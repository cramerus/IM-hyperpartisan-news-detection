# %%
import pandas as pd
import numpy as np
import sklearn as sk
from tqdm import tqdm
import ast
import csv
import glob
import pickle

csv.field_size_limit(100000000)
# Out:
# 131072

# %% [markdown]
# # Read in csv datasets

# %%
files = glob.glob('data/train_df_spacy*.csv')

# %%
# attempting on a .1 random sampled set

test_df = pd.read_csv('data/test_df_spacy.csv').sample(frac=.1, random_state=123)

frames = []
for file in files:
    frames.append(pd.read_csv(file).sample(frac=.1, random_state=123))
train_df = pd.concat(frames)

# %%
test_df.head()
# Out:
#                                                title  label          bias  \
# 0  SAN FRANCISCO / Head of Juvenile Probation Dep...  False   left-center
# 1  University leaders ban pro-life flag display, ...   True         right
# 2  DONALD TRUMP, GET YOUR TINY PIGGY PERVERT HAND...   True          left
# 3  DIRTY: Hillary Clinton Implies Trump is a Nazi...   True         right
# 4                             A Bipartisan Work Plan  False  right-center
#
#                                         title_lemmas  \
# 0  ('san', 'francisco', '/', 'head', 'of', 'juven...
# 1  ('university', 'leader', 'ban', 'pro', '-', 'l...
# 2  ('donald', 'trump', ',', 'get', 'your', 'tiny'...
# 3  ('dirty', ':', 'hillary', 'clinton', 'implies'...
# 4                ('a', 'bipartisan', 'work', 'plan')
#
#                                            title_pos  \
# 0  ('PROPN', 'PROPN', 'SYM', 'PROPN', 'ADP', 'PRO...
# 1  ('NOUN', 'NOUN', 'VERB', 'ADJ', 'PUNCT', 'NOUN...
# 2  ('NUM', 'NOUN', 'PUNCT', 'VERB', 'ADJ', 'ADJ',...
# 3  ('NOUN', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', '...
# 4                   ('DET', 'PROPN', 'NOUN', 'NOUN')
#
#                                           title_tags  \
# 0  ('NNP', 'NNP', 'SYM', 'NNP', 'IN', 'NNP', 'NNP...
# 1  ('NN', 'NNS', 'VBP', 'JJ', ',', 'NN', 'NN', 'N...
# 2  ('CD', 'NN', ',', 'VB', 'PRP$', 'JJ', 'NNP', '...
# 3  ('NNS', ':', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ'...
# 4                          ('DT', 'NNP', 'NN', 'NN')
#
#                                           title_deps
# 0  ('compound', 'nsubj', 'punct', 'appos', 'prep'...
# 1  ('compound', 'nsubj', 'ROOT', 'amod', 'punct',...
# 2  ('compound', 'nsubj', 'punct', 'ROOT', 'poss',...
# 3  ('ROOT', 'punct', 'compound', 'nsubj', 'compou...
# 4            ('det', 'compound', 'compound', 'ROOT')

# %%
train_df.head()
# Out:
#                                                title  label          bias  \
# 0  After DeVos Announced Plans To Reexamine Title...   True         right
# 1  University To Award Trayvon Martin With Posthu...   True         right
# 2  Texas State University suspends Greek life aft...  False  right-center
# 3  Jewish Organization's Huge Day Of Unity On Tue...   True         right
# 4  BREAKING: Trump Reaches Agreement To Keep 1,00...   True         right
#
#                                         title_lemmas  \
# 0  ('after', 'devos', 'announced', 'plans', 'to',...
# 1  ('university', 'to', 'award', 'trayvon', 'mart...
# 2  ('texas', 'state', 'university', 'suspend', 'g...
# 3  ('jewish', 'organization', "'s", 'huge', 'day'...
# 4  ('break', ':', 'trump', 'reaches', 'agreement'...
#
#                                            title_pos  \
# 0  ('ADP', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'PRO...
# 1  ('PROPN', 'ADP', 'PROPN', 'PROPN', 'PROPN', 'A...
# 2  ('PROPN', 'PROPN', 'PROPN', 'VERB', 'ADJ', 'NO...
# 3  ('PROPN', 'PROPN', 'PART', 'PROPN', 'PROPN', '...
# 4  ('VERB', 'PUNCT', 'PROPN', 'PROPN', 'NOUN', 'P...
#
#                                           title_tags  \
# 0  ('IN', 'NNP', 'NNP', 'NNPS', 'IN', 'NNP', 'NNP...
# 1  ('NNP', 'IN', 'NNP', 'NNP', 'NNP', 'IN', 'NNP'...
# 2  ('NNP', 'NNP', 'NNP', 'VBZ', 'JJ', 'NN', 'IN',...
# 3  ('NNP', 'NNP', 'POS', 'NNP', 'NNP', 'IN', 'NNP...
# 4  ('VBG', ':', 'NNP', 'NNP', 'NN', 'TO', 'VB', '...
#
#                                           title_deps
# 0  ('prep', 'pobj', 'compound', 'ROOT', 'prep', '...
# 1  ('compound', 'prep', 'pobj', 'compound', 'ROOT...
# 2  ('compound', 'compound', 'nsubj', 'ROOT', 'amo...
# 3  ('amod', 'poss', 'case', 'compound', 'ROOT', '...
# 4  ('ROOT', 'punct', 'compound', 'compound', 'ROO...

# %% [markdown]
# # setup for initial model experimentation

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC

# %%
def dummy(doc):
    # use as param in vectorizers
    return ast.literal_eval(doc)

# %%
count_uni = CountVectorizer(stop_words = 'english',
                    analyzer='word',
                    tokenizer=dummy,
                    preprocessor=None,
                    max_features = 5000)
tfidf_uni = TfidfVectorizer(stop_words = 'english',
                    analyzer='word',
                    tokenizer=dummy,
                    preprocessor=None,
                    max_features = 5000)
count_bi = CountVectorizer(stop_words = 'english',
                    analyzer='word',
                    tokenizer=dummy,
                    preprocessor=None,
                    ngram_range=(1,2),
                    max_features = 10000)
tfidf_bi = TfidfVectorizer(stop_words = 'english',
                    analyzer='word',
                    tokenizer=dummy,
                    preprocessor=None,
                    ngram_range=(1,2),
                    max_features = 10000)

# %%
dt = DecisionTreeClassifier()
lr = LogisticRegression(verbose=True)
svm = LinearSVC(verbose=True)
mlp = MLPClassifier(verbose=True)

# %%
def model(model, vectorizer, x_train, y_train, x_test, y_test):
    # train a model (can be various kinds) & evaluate
    
    x_train_use = vectorizer.fit_transform(x_train) # if using dask, add x_train.compute()
    x_test_use = vectorizer.transform(x_test)
    
    model = model.fit(x_train_use, y_train)
    y_pred = model.predict(x_test_use)
    
    acc = sk.metrics.accuracy_score(y_test, y_pred)
    print("accuracy: {0:.2f}%".format(acc*100))
    
    mapping = list(zip(vectorizer.get_feature_names(), model.coef_[0]))
    mapping.sort(key=lambda x: abs(x[1]))
    mapping.reverse()
    
    return mapping

# %%
y_train = train_df['label']
y_test = test_df['label']

# %%
x_train = train_df['title_lemmas']
x_test = test_df['title_lemmas']

# %% [markdown]
# # logistic regression + count vectors: pre-vocab cut

# %%
lr_count_uni = model(lr, count_uni, x_train, y_train, x_test, y_test)
# Out:
# [LibLinear]accuracy: 57.35%

# %%
lr_count_uni
# Out:
# [('abq', -5.232931584343739),
#  ('nm', -5.085423494676702),
#  ('unm', -4.854699152587665),
#  ('new mexico', -4.8337045556664275),
#  ('lobo', -4.518975078048932),
#  ('lobos', -4.488506540816385),
#  ('truthdigger', 4.412166277205591),
#  ('lottery', -4.364574812142593),
#  ('apd', -4.164392767614455),
#  ('topes', -4.115008008766362),
#  ('aps', -4.11276172181072),
#  ('tope', -3.9388203686084706),
#  ('aggie', -3.8593462847602185),
#  ('nmsu', -3.8003278759889914),
#  ('editorial', -3.7917793447341865),
#  ('baptists', -3.7879718771974216),
#  ('sbc', -3.7369465487718463),
#  ('albuquerque', -3.732258927299884),
#  ('fe', -3.7307242356079127),
#  ('calwatchdog', -3.6985887257982255),
#  ('rr', -3.6250714767328827),
#  ('cruces', -3.588170579619929),
#  ('pnm', -3.5699972619071056),
#  ('wp', -3.554707325789891),
#  ('abby', -3.5521510042370275),
#  ('forex', -3.5249344785421237),
#  ('goings', -3.4640105704343522),
#  ('lanl', -3.43915501498149),
#  ('slumped', 3.4299379400481658),
#  ('sandia', -3.3915608068208445),
#  ('jumped', 3.363330596391592),
#  ('carlsbad', -3.357259112481828),
#  ('farmington', -3.3338142072812524),
#  ('cbf', -3.259215664132165),
#  ('mojo', 3.2520482127192705),
#  ('gsk', -3.245125429881963),
#  ('brodner', 3.2257560603907307),
#  ('etf', 3.220133479309344),
#  ('wipp', -3.2197712838254557),
#  ('taos', -3.1913579196208257),
#  ('dazzle', -3.18882619831456),
#  ('dwi', -3.181061362057037),
#  ('shapiro', 3.1602234813994743),
#  ('chatter', -3.0607202544740253),
#  ('navajo', -3.0598376477399953),
#  ('cnm', -3.0566313221011554),
#  ('bernalillo', -2.990381935163378),
#  ('rancho', -2.981778899600942),
#  ('diocese', -2.980098385829548),
#  ('brief', -2.976710048207753),
#  ('nkorea', -2.95893919490054),
#  ('mulesoft', -2.9361099772007053),
#  ('roswell', -2.9324112191687504),
#  ('bosque', -2.9308177368976795),
#  ('geo', -2.9223393383472804),
#  ('i-25', -2.886485583547031),
#  ('i-40', -2.8836827089846966),
#  ('paseo', -2.8805485315693633),
#  ('pueblo', -2.8790298138711594),
#  ('fmr', 2.8633555344662582),
#  ('trumpcare', 2.8209245112058907),
#  ('seminary', -2.814767463714414),
#  ('chomsky', 2.7584773332999326),
#  ('terrorists', 2.7473053089448034),
#  ('councilor', -2.7374040335457708),
#  ('earnings', 2.737012113090926),
#  ('playoff', -2.7362874435618902),
#  ('martinez', -2.698900187101999),
#  ('mudslide', -2.6764710958471234),
#  ('rb', -2.6722375499781204),
#  ('socialism', 2.639738255487049),
#  ('wapo', 2.612581200836829),
#  ('cps', -2.5903846829068744),
#  ('pearce', -2.5779633786914298),
#  ('sandoval', -2.571381590838156),
#  ('lol', 2.568540698062185),
#  ('ca', -2.557624950643789),
#  ('baptist', -2.546254743237068),
#  ('cueva', -2.5449641748741194),
#  ('shares', 2.5434898613142063),
#  ('therapeutics', 2.529768220881181),
#  ('wr', -2.497181872432211),
#  ('cibola', -2.497139743106049),
#  ('tourney', -2.4875395750832627),
#  ('neal', -2.4789323539438017),
#  ('™', -2.474899281446356),
#  ('5a', -2.4692160250863946),
#  ('baylor', -2.451555389872296),
#  ('liberals', 2.446833082206775),
#  ('fiesta', -2.4071871979304698),
#  ('ot', -2.406353715298912),
#  ('popped', 2.3737215764907136),
#  ('leftist', 2.3693034537886346),
#  ('mwc', -2.3311053481301944),
#  ('ways', 2.3079282149738636),
#  ('bcso', -2.3056268665494537),
#  ('mocks', 2.298004614574606),
#  ('factcheck', -2.296684621495672),
#  ('composite', -2.2920087889510388),
#  ('palin', 2.283280012701939),
#  ('reasons', 2.2827035697759155),
#  ('gays', 2.267910450222495),
#  ('stocks', 2.2602390506414403),
#  ('coordinator', -2.2479383478885215),
#  ('nader', 2.2454731184715206),
#  ('qb', -2.2232946633973074),
#  ('hospitalize', -2.2229037166194803),
#  ('udall', -2.2223648537544816),
#  ('workers', 2.1911345366434656),
#  ('investors', 2.186230562513205),
#  ('feminist', 2.1855294741612687),
#  ('results', 2.1756565446533718),
#  ('olbermann', 2.1683576507897406),
#  ('refuses', 2.1609169154839223),
#  ('limbaugh', 2.1567876984264016),
#  ('dose', -2.145998486045771),
#  ('regent', -2.1442815586845714),
#  ('rapture', 2.1395699875249177),
#  ('sf', -2.11539486641939),
#  ('exhibition', -2.114189417022286),
#  ('billions', 2.113689402578109),
#  ('eagles', -2.107337314992318),
#  ('archdiocese', -2.103205235540337),
#  ('cal', -2.0953524364652036),
#  ('sanchez', -2.0920171226999473),
#  ('jumps', 2.0780885712174753),
#  ('mma', -2.0660229218322876),
#  ('thug', 2.055413898589594),
#  ('tariff', -2.0540300005219034),
#  ('tries', 2.0460327150118074),
#  ('draw', -2.044457267041498),
#  ('scheer', 2.041094919196845),
#  ('retailers', 2.034201376336997),
#  ('hiker', -2.0306494696892976),
#  ('pistorius', -2.0306455497192637),
#  ('sales', 2.022707817002251),
#  ('cheney', 2.013729435637178),
#  ('championship', -2.011991393831738),
#  ('students', 2.008679975244312),
#  ('sharpton', 2.0074588631681225),
#  ('finalist', -2.0062632001621092),
#  ('grain', 1.995431284280672),
#  ('priest', -1.9928518728059357),
#  ('tournament', -1.991530025678295),
#  ('ferry', -1.9914280902921309),
#  ('mesa', -1.983424621481881),
#  ('beats', 1.9756222009874438),
#  ('myanmar', -1.9751228983794367),
#  ('lieberman', 1.9673339741939926),
#  ('futures', 1.9660687952731637),
#  ('rumsfeld', 1.9607499933882395),
#  ('traders', 1.9575689228277056),
#  ('profits', 1.9540686654084507),
#  ('notebook', -1.9448355077358637),
#  ('nukes', 1.9371513772619249),
#  ('disgusting', 1.9364775701121169),
#  ('attempts', 1.934789077377671),
#  ('files', 1.9344986251764225),
#  ('clovis', -1.9327088146130307),
#  ('los', -1.9253028568929829),
#  ('mali', -1.9239589695107546),
#  ('skier', -1.9236013714998805),
#  ('beck', 1.9235293212448286),
#  ('j.c.', 1.9218990436810288),
#  ('6a', -1.9164820098464674),
#  ('bans', 1.9120541764371966),
#  ('snapshot', 1.9068641128888735),
#  ('cardinals', -1.9068254091201717),
#  ('mistakes', 1.905483485472993),
#  ('fuels', 1.9045084330081758),
#  ('aussie', -1.8902160265654238),
#  ('resorts', 1.8899397767951114),
#  ('pedestrian', -1.889822902293701),
#  ('blackwater', 1.872933641622625),
#  ('trooper', -1.8726660188091029),
#  ('viking', -1.8716244904098933),
#  ('opener', -1.8698770030027578),
#  ('ministry', -1.8664745698718115),
#  ('lies', 1.8662180391873262),
#  ('pharmaceuticals', 1.8607439099988068),
#  ('ne', -1.8604807388591267),
#  ('slaying', -1.8584905063409005),
#  ('rt', -1.852106464279244),
#  ('markets', 1.8377927687777618),
#  ('accounts', 1.83496141036915),
#  ('fascism', 1.8317770866968215),
#  ('dividend', 1.8290901110434858),
#  ('expectations', 1.8173815739309545),
#  ('globes', -1.8098921916614419),
#  ('browns', -1.8082031441876036),
#  ('capitalism', 1.8022836743422268),
#  ('instant', 1.7964802810214247),
#  ('antifa', 1.7913428794358328),
#  ('worst', 1.788386287335722),
#  ('ltd.', 1.786339040957206),
#  ('investing', 1.7806135624797865),
#  ('prophecy', 1.7804522008444714),
#  ('ira', 1.7801611587284094),
#  ('soars', 1.7795157507914927),
#  ('savings', 1.7765718755453845),
#  ('socialist', 1.7722210281938575),
#  ('posts', 1.7689111477621184),
#  ('dividends', 1.7670329848077142),
#  ('analysis', -1.766431825863226),
#  ('racing', -1.7608093235465205),
#  ('protesters', 1.757003874493083),
#  ('eco', 1.7494978835968504),
#  ('burglary', -1.7488539994463768),
#  ('laws', 1.7458398987455441),
#  ('krugman', 1.7458331556809044),
#  ('goods', 1.740853077208477),
#  ('falter', -1.7380828623098858),
#  ('imperial', 1.7351621106255348),
#  ('rim', 1.7317648504759195),
#  ('rejects', 1.7256666271009051),
#  ('newt', 1.7183931360967097),
#  ('cards', 1.70875817232078),
#  ('insane', 1.7081594294403906),
#  ('tells', 1.70587849437068),
#  ('stores', 1.7047740581661808),
#  ('climbs', 1.699172949968499),
#  ('aig', 1.6973395253233965),
#  ('premiere', -1.6959653645281514),
#  ('approves', 1.6911079604665962),
#  ('threatens', 1.6898510789445693),
#  ('thousands', 1.6883621032144815),
#  ('clergy', -1.6852456643289746),
#  ('arms', 1.681648255282565),
#  ('bachmann', 1.6792106771619564),
#  ('immigrants', 1.6788537735339792),
#  ('evening’', -1.6784742718757437),
#  ('selloff', 1.6753607402079933),
#  ('gitmo', 1.673871597826224),
#  ('won', 1.6675157859316676),
#  ('breaks', 1.6669627276205987),
#  ('p.m.', 1.6639264447068478),
#  ('linkedin', 1.6628739079421178),
#  ('prep', -1.658943014990644),
#  ('civilians', 1.6589005412383389),
#  ('msnbc', 1.6572031787865737),
#  ('feminism', 1.6557122427333952),
#  ('brands', 1.6539585149783136),
#  ('teachers', 1.6533081274302812),
#  ('smear', 1.6519688545010514),
#  ('score', -1.6386766607469831),
#  ('passes', 1.6375048276343391),
#  ('condo', -1.6373916449454073),
#  ('banks', 1.63666337301852),
#  ('scotus', 1.6334467340219585),
#  ('avalanche', -1.6332273359356038),
#  ('rallies', 1.6292978422602369),
#  ('motors', 1.6268256628282907),
#  ('empire', 1.624563910231664),
#  ('jaguar', -1.623449773357655),
#  ('armour', 1.6209064235969173),
#  ('lifts', 1.6206224482377585),
#  ('plays', 1.6188900656936636),
#  ('loud', -1.618477494517175),
#  ('sacramento', -1.6170773563948375),
#  ('idiot', 1.6165400388706377),
#  ('releases', 1.6156113345116963),
#  ('bombshell', 1.614908858629456),
#  ('—', 1.6125814659886988),
#  ('compares', 1.610228833861195),
#  ('zoo', -1.6077929524791732),
#  ('wants', 1.606085929615706),
#  ('sox', -1.605471652443292),
#  ('plc', 1.6039650129944978),
#  ('corp.', 1.601986770471266),
#  ('gaddafi', -1.601869017998798),
#  ('cisco', 1.6013155880480485),
#  ('fitbit', 1.5981102985278186),
#  ('payer', 1.5912742519692273),
#  ('details', 1.5904509668949978),
#  ('tropical', -1.5902478100788688),
#  ('peru', -1.5883427238551027),
#  ('bishop', -1.5879995127691526),
#  ('newest', 1.5861354072945566),
#  ('conservatives', 1.5858058252052551),
#  ('occupation', 1.5850106506393622),
#  ('opinion', -1.583563184035714),
#  ('desk', -1.5771380694102382),
#  ('procter', 1.5754560236311923),
#  ('refugees', 1.5712685858265802),
#  ('fracking', 1.5665998801604122),
#  ('tran', -1.5633029222495873),
#  ('companies', 1.5614952293314903),
#  ('rates', 1.5609441745274883),
#  ('bush', 1.5538915826334754),
#  ('usda', 1.5522831701484485),
#  ('activists', 1.5520761704337838),
#  ('saved', 1.5495522520208074),
#  ('hilarious', 1.5445057052938092),
#  ('inc.', 1.5433108929304344),
#  ('balloon', -1.5394483133295236),
#  ('probation', -1.535572782986509),
#  ('settles', 1.533183223462703),
#  ('bombs', 1.5326660061654727),
#  ('employees', 1.531896104288669),
#  ('editor', -1.5310689565439228),
#  ('hosts', 1.5307872644065952),
#  ('swear', -1.5252635012041873),
#  ('sciences', 1.5202412800460963),
#  ('hillary', 1.5193124525816954),
#  ('slay', -1.5129434402833228),
#  ('leaked', 1.512846917178948),
#  ('column', -1.5124086190849217),
#  ('leaves', 1.5116271145503617),
#  ('things', 1.5115865102091277),
#  ('ranch', -1.5077095796754556),
#  ('officials', 1.5069149460360869),
#  ('jobs', 1.5050978763493905),
#  ('wsj', 1.504760657544894),
#  ('nuts', 1.5034932703394406),
#  ('musician', -1.5017548628136193),
#  ('members', 1.4999980007645854),
#  ('trio', -1.496099786471444),
#  ('kenya', -1.4922784961799844),
#  ('lightning', -1.4908191371390658),
#  ('evaluation', -1.489646196247924),
#  ('nvidia', 1.4888847830238103),
#  ('endorses', 1.4871048645560088),
#  ('owners', 1.485459067439509),
#  ('products', 1.4761244789695456),
#  ('kellyanne', 1.4732628375424717),
#  ('citizens', 1.472677865913723),
#  ('crimea', -1.467017308321903),
#  ('thailand', -1.4651000477660785),
#  ('sexist', 1.464690562728618),
#  ('eligible', -1.4628324929065644),
#  ('title', -1.462252052771436),
#  ('silicon', 1.4622358999822989),
#  ('dissent', 1.4617691749524915),
#  ('401(k', 1.459852274609649),
#  ('firefighter', -1.4581883943095577),
#  ('79', -1.4577280824756051),
#  ('angeles', 1.4566771417808684),
#  ('coach', -1.45614002629367),
#  ('bangladesh', -1.455571761864756),
#  ('loans', 1.452679950243898),
#  ('eia', 1.4522627225758924),
#  ('ftse', 1.4484069282569927),
#  ('recalls', 1.4478029079058166),
#  ('moments', 1.4466945162790497),
#  ('maddow', 1.4445109706736536),
#  ('losses', 1.443979176020662),
#  ('embezzlement', -1.4432761709880932),
#  ('deputy', -1.4420734140561335),
#  ('strikes', 1.4415837951240424),
#  ('zimbabwe', -1.439043700374297),
#  ('volleyball', -1.438144819554434),
#  ('elections', 1.4324894232785808),
#  ('kills', 1.4281737872556108),
#  ('trudeau', 1.4275401233481024),
#  ('rove', 1.4253115991607395),
#  ('hannity', 1.4230789283540406),
#  ('quarterly', 1.4204781328800125),
#  ('jackpot', -1.4202888891471475),
#  ('buys', 1.4164854229956114),
#  ('paso', -1.4162503913080067),
#  ('rout', -1.4134945821822018),
#  ('tweets', 1.4132701704678132),
#  ('kkk', 1.4126998262575037),
#  ('hypocrisy', 1.4110375456511661),
#  ('boxing', -1.4086469540916002),
#  ('fugitive', -1.4048000597461254),
#  ('lines', 1.40302744811695),
#  ('fell', 1.398089749033934),
#  ('mag', -1.3940668576304645),
#  ('variety', -1.3920633300080607),
#  ('digest', -1.3909723808448866),
#  ('speaks', 1.3908235589365159),
#  ('moves', 1.3901090600317794),
#  ('scores', 1.3899936077576185),
#  ('hands', 1.389485200858854),
#  ('wins', 1.3875437649554518),
#  ('blasio', 1.3874371867695146),
#  ('hsbc', 1.3845217812523405),
#  ('chipotle', 1.3835714554347736),
#  ('scalia', 1.38129199148155),
#  ('weiner', 1.3811402773911496),
#  ('rookie', -1.379966474894907),
#  ('n.', -1.379697833245443),
#  ('feds', 1.3794846861577075),
#  ('dispatch', 1.3770934077366146),
#  ('astronaut', -1.3743724985734818),
#  ('ap', -1.3739732361590091),
#  ('pushes', 1.372928984176218),
#  ('gallup', -1.3703912989747824),
#  ('pc', 1.368561845232153),
#  ('left', 1.3674513318716826),
#  ('fl', 1.3671790003491489),
#  ('bp', 1.3661977488045962),
#  ('pretribulation', 1.3660188300901233),
#  ('midday’', -1.364702057614445),
#  ('groups', 1.3643171198032045),
#  ('pledges', 1.3639273902750153),
#  ('costco', 1.3611530456281673),
#  ('volcano', -1.3596154910406768),
#  ('nike', 1.3596069830831858),
#  ('pair', -1.356629498768725),
#  ('misconduct', -1.354118970487066),
#  ('ana', -1.3535310376726168),
#  ('trayvon', 1.3535127491544239),
#  ('church', -1.3529644001925472),
#  ('breitbart', 1.350363922295895),
#  ('5’', -1.3491093317739073),
#  ('pfizer', 1.347048311892887),
#  ('flashback', 1.3459284329610601),
#  ('volume', 1.344697696466688),
#  ('philippine', -1.3426779025214826),
#  ('catholics', -1.339373247903973),
#  ('rahm', 1.3354453938575543),
#  ('megyn', 1.334871858299407),
#  ('rights', 1.3343122965209517),
#  ('relation', -1.3329690584104799),
#  ('weighs', 1.3329568489455639),
#  ('volatility', 1.3310664758115989),
#  ('mexico', -1.3301506186481824),
#  ('homicide', -1.3288827062531028),
#  ('49er', -1.3285458348463939),
#  ('73', -1.3274149805491706),
#  ('bernanke', 1.3252058304115844),
#  ('assets', 1.3250352867155024),
#  ('hoop', -1.3246473289047724),
#  ('tensions', 1.323808949318284),
#  ('corporation', 1.3231726818728655),
#  ('pedophile', 1.320356762140502),
#  ('koch', 1.3200340988977106),
#  ('torture', 1.3195158907436453),
#  ('guess', 1.3195077386161023),
#  ('beast', 1.318867893832058),
#  ('journal', -1.3146651579398303),
#  ('waiver', -1.314262739672973),
#  ('paypal', 1.3133284983823608),
#  ('barclays', 1.313263189658808),
#  ('madoff', 1.3112475662124135),
#  ('protests', 1.3101273679710144),
#  ('berry', -1.3050016395772308),
#  ('roundup', 1.3048952799309592),
#  ('researcher', -1.3043892328345839),
#  ('votes', 1.3029031936065505),
#  ('cancels', 1.3027121658491125),
#  ('working', 1.301086483332535),
#  ('ram', -1.300327643833462),
#  ('valeant', 1.293541300163084),
#  ('biggest', 1.2876580384819758),
#  ('nokia', 1.2865420144337196),
#  ('74', -1.285210270925501),
#  ('fox', 1.2836317268488011),
#  ('puts', 1.283229044519053),
#  ('amazon.com', 1.2831808905060682),
#  ('highest', 1.2801451164544566),
#  ('reopen', -1.279803098459526),
#  ('attacks', 1.2783343855882847),
#  ('cars', 1.2782522824258842),
#  ('industries', 1.2776035149098677),
#  ('responds', 1.2748024999764918),
#  ('children', 1.2736109060726548),
#  ('politics', 1.2719950886052933),
#  ('names', 1.2715895703258295),
#  ('lawmakers', 1.2703241419817446),
#  ('reflect', -1.2700899087334665),
#  ('78', -1.269531692301059),
#  ('sport', -1.267494989501935),
#  ('tennis', -1.2674195491149534),
#  ('saint', -1.2649137559181802),
#  ('surgery', -1.2636319428585299),
#  ('ton', -1.2629739488818783),
#  ('rules', 1.2617923956232124),
#  ('honor', -1.260843678044722),
#  ('india', -1.2607978061415326),
#  ('corporate', 1.2593657352836094),
#  ('evil', 1.2593083927700883),
#  ('endanger', -1.258738293456752),
#  ('streets', 1.2571328130058446),
#  ('meltdown', 1.2570544735543205),
#  ('govt', -1.2566505800400043),
#  ('injure', -1.256341547351511),
#  ('rio', -1.254166859471861),
#  ('39', -1.2539456109092761),
#  ('sochi', -1.2537743605462055),
#  ('agrees', 1.2534994954307315),
#  ('83', -1.25203185212047),
#  ('specie', -1.2518318622115558),
#  ('fishing', -1.2489375475034763),
#  ('nasdaq', 1.2484943997171265),
#  ('pct', -1.2483878335016534),
#  ('hell', 1.247731155952923),
#  ('slips', 1.2476901951332093),
#  ('76', -1.245589374767891),
#  ('colorado', -1.2443911809648478),
#  ('greatest', 1.2429212746713592),
#  ('saddam', 1.2425158511733103),
#  ('dope', -1.2409702150902675),
#  ('targets', 1.2405726640022456),
#  ('kids', 1.240455393227253),
#  ('weapons', 1.2402634360247993),
#  ('wages', 1.239710148077688),
#  ('labels', -1.2373381697360368),
#  ('billy', -1.235151797208895),
#  ('liberal', 1.2335676611780786),
#  ('arson', -1.2326472458860978),
#  ('minutes', 1.2323895918312735),
#  ('checks', 1.2319039044540998),
#  ('biotech', 1.2306322979517097),
#  ('museum', -1.2301073353137648),
#  ('southeast', -1.229811395626442),
#  ('reunite', -1.229062037471559),
#  ('injury', -1.2277985413381596),
#  ('got', 1.2259915840514255),
#  ('highs', 1.2237530138285855),
#  ('fifa', -1.2230955190839838),
#  ('continues', 1.2223558451574612),
#  ('colbert', 1.2223444984537555),
#  ('nypd', 1.2221339847867903),
#  ('threats', 1.2221312636424524),
#  ('pays', 1.220413474725202),
#  ('ioc', -1.2187807796011942),
#  ('gopro', 1.2155415761850843),
#  ('89', -1.215321435798678),
#  ('barcelona', -1.2151954528295146),
#  ('…', 1.2141926865756123),
#  ('backs', 1.2141437095403178),
#  ('evacuate', -1.2119914214340415),
#  ('champ', -1.2105717470472923),
#  ('pulls', 1.207762118625231),
#  ('caught', 1.2062582943160243),
#  ('bernie', 1.2047511062979182),
#  ('shall', 1.20348286299302),
#  ('warns', 1.2018788834083465),
#  ('apartheid', 1.2007621807641182),
#  ('shootout', -1.2005467066274969),
#  ('basketball', -1.1998220789066985),
#  ('orders', 1.199103530512321),
#  ('programs', 1.1959711697812552),
#  ('dell', 1.195565928183356),
#  ('principal', -1.1952183241392442),
#  ('gains', 1.1940089383560624),
#  ('oliver', 1.1934457623870307),
#  ('married', 1.191718944183693),
#  ('considers', 1.191269104858015),
#  ('gallery', -1.191231413329944),
#  ('madrid', -1.1907973040214055),
#  ('newspaper', -1.1907249580698585),
#  ('aramco', -1.1902789895107166),
#  ('snl', 1.1900875777664208),
#  ('ipad', 1.1899719747626094),
#  ('grant', -1.189787085687159),
#  ('a&m', -1.1892353831946418),
#  ('thriller', -1.1881419892112473),
#  ('sag', -1.1873331627176231),
#  ('snow', -1.186946848467479),
#  ('cuts', 1.1865826340147245),
#  ('treasury', 1.1864279300839002),
#  ('tea', 1.1860846802667577),
#  ('kicks', 1.1847008350026706),
#  ('yankees', -1.1842685021632042),
#  ('ordinance', -1.1823957768677889),
#  ('yeah', 1.1821153536969966),
#  ('nixon', 1.1814178395691182),
#  ('enjoy', -1.1806224044805556),
#  ('cash’', -1.179598544088966),
#  ('fears', 1.17873860855698),
#  ('jazz', -1.1781253597830657),
#  ('pharma', 1.177676344628005),
#  ('77', -1.176708795797693),
#  ('maher', 1.175996940796428),
#  ('ignores', 1.1759825568541704),
#  ('mitch', 1.17522419344446),
#  ('band', -1.1743972050726046),
#  ('monsanto', 1.1743302103247342),
#  ('downtown', -1.1738772783195361),
#  ('vista', -1.1726557169252636),
#  ('marketing', 1.1724600197179686),
#  ('tucker', 1.1717054036887413),
#  ('arnold', -1.1705179136560924),
#  ('county', -1.1697649539711625),
#  ('misses', 1.164315455347141),
#  ('curry', -1.1628039510197925),
#  ('illegal', 1.162220783277188),
#  ('q2', 1.1621163338790534),
#  ('wendy', 1.1610359453549803),
#  ('victims', 1.1602053329254498),
#  ('damn', 1.1590508173671048),
#  ('pandora', 1.1584327598064266),
#  ('benghazi', 1.1580132166804065),
#  ('broadway', -1.1580064174894638),
#  ('rebels', 1.1565307012344956),
#  ('suspect', -1.156484409784275),
#  ('a.m.', 1.1542818059237845),
#  ('offense', -1.1540279695170128),
#  ('rapist', 1.150490251295681),
#  ('sanctions', 1.1500699553190445),
#  ('forces', 1.1499595906737097),
#  ('allegation', -1.149790330020327),
#  ('progressive', 1.1493764850080617),
#  ('vital', -1.1493103854923867),
#  ('lotto', -1.1492473804324501),
#  ('85', -1.14911821206645),
#  ('women', 1.14682787919315),
#  ('friends', 1.1454651108265905),
#  ('explore', -1.1451936390920467),
#  ('rips', 1.1437228662107275),
#  ('pictures', 1.1434580849895801),
#  ('monument', -1.142855999674771),
#  ('0', -1.1425998042341847),
#  ('volunteer', -1.1417243565384436),
#  ('said', 1.1408584576564589),
#  ('gilead', 1.1400703062827586),
#  ('partners', 1.1396830942843084),
#  ('blasts', 1.1394387216563804),
#  ('flavor', -1.1394384710482808),
#  ('singer', -1.138761015589986),
#  ('cities', 1.1381765931967587),
#  ('finale', -1.137873394644372),
#  ('athletic', -1.1375100462806962),
#  ('aca', -1.1366080153591673),
#  ('falsely', 1.1356860914520486),
#  ('fool', 1.1347003976716792),
#  ('59', -1.1342204640018425),
#  ('2009', 1.1339185187360614),
#  ('festival', -1.133022142473557),
#  ('petraeus', 1.1329467059511193),
#  ('brutality', 1.132620139683261),
#  ('faith', -1.1315187063111),
#  ('audio', 1.1306204946720226),
#  ('spotlight', -1.1305458788380798),
#  ('terrible', 1.1299133857458614),
#  ('troops', 1.129890921643454),
#  ('pit', -1.128212542218789),
#  ('forum', -1.1277839980455386),
#  ('tpp', 1.1276374484119194),
#  ('bless', 1.127396519328738),
#  ('bernardino', 1.1262568994892859),
#  ('cnn', 1.1250650387141117),
#  ('rohingya', -1.1242818089037692),
#  ('pa', 1.124278187991257),
#  ('quotes', 1.1240948270084616),
#  ('coulter', 1.1235235467370603),
#  ('bonds', 1.12137279466081),
#  ('57', -1.1211242869427296),
#  ('somalia', -1.120990179889183),
#  ('shootings', 1.1209480771012115),
#  ('cops', 1.1203863603544608),
#  ('laden', 1.1201530739088494),
#  ('15-year', 1.117845925763602),
#  ('miller', -1.1174469151488275),
#  ('funds', 1.1165393686855745),
#  ('giuliani', 1.1159745497070517),
#  ('oracle', 1.115925139015575),
#  ('lilly', 1.115181535832909),
#  ('holdings', 1.1146148919831866),
#  ('boehner', 1.1141003143539991),
#  ('nab', -1.1138811064524297),
#  ('wars', 1.1134774438038963),
#  ('mln', -1.113030304221215),
#  ('87', -1.1124566849429642),
#  ('plead', -1.110498614503489),
#  ('revolt', 1.1101472231904728),
#  ('norway', -1.1097125124536154),
#  ('69', -1.109266213908065),
#  ('largest', 1.1089183979488684),
#  ('lands', 1.107976278105455),
#  ('woes', 1.107912849663117),
#  ('winners', 1.1069725153266574),
#  ('dictator', 1.1054790713161589),
#  ('kenyan', -1.1054090937868661),
#  ('displace', -1.1045326203598254),
#  ('del', -1.104302064714464),
#  ('supporters', 1.1039924261565506),
#  ('men', 1.1036211811024537),
#  ('francisco', 1.103131770398698),
#  ('nigeria', -1.1028667737730584),
#  ('3q', 1.1028502675712302),
#  ('horse', -1.102850002865104),
#  ('apartment', -1.1016244983051655),
#  ('uganda', -1.1014499353115879),
#  ('twin', -1.0982338660182733),
#  ('tips', 1.0979006384495418),
#  ('communications', 1.0974990031245404),
#  ('tour', -1.09539828830636),
#  ('recommend', -1.0951605355015768),
#  ('claims', 1.0947593474015962),
#  ('sexism', 1.093303515186255),
#  ('2005', -1.092984348648699),
#  ('tops', 1.0917550200404014),
#  ('samsung', 1.0905834342027156),
#  ('tucson', -1.0894137175868241),
#  ('preserve', -1.0887133352810456),
#  (']', 1.0884104858671826),
#  ('millennials', 1.0883668909126243),
#  ('phoenix', -1.087975848609197),
#  ('technologies', 1.0870113619990451),
#  ('heritage', -1.0851952179924056),
#  ('dinosaur', -1.0842014921812795),
#  ('autopsy', -1.083583186982731),
#  ('robbery', -1.0832424458337668),
#  ('madness', 1.0821075559696796),
#  ('devices', 1.0817480217955682),
#  ('boeing', 1.0799792507571773),
#  ('reports', 1.079035172735079),
#  ('resigns', 1.0787876195809547),
#  ('occupy', 1.0765330862954328),
#  ('racist', 1.0742593713016808),
#  ('81', -1.0742556115815691),
#  ('mosul', -1.0737023428965775),
#  ('birthday', -1.0735191266684392),
#  ('rail', -1.0730004307909953),
#  ('cardinal', -1.072854038672775),
#  ('fame', -1.0714165708713106),
#  ('corn', 1.071309161857325),
#  ('pet', -1.071191864238514),
#  ('accuse', -1.0704731989088907),
#  ('duterte', -1.068755311516745),
#  ('raises', 1.0657818440669382),
#  ('chile', -1.0652315285501839),
#  ('legislature', -1.0651751213860248),
#  ('north carolina', -1.0630452135592445),
#  ('freak', 1.0615341256447999),
#  ('item', -1.060002351505188),
#  ('recover', -1.059494233098294),
#  ('%', 1.058327606065374),
#  ('absurd', 1.0575600480145608),
#  ('sentence', -1.0571980133302856),
#  ('ethic', -1.0547013867769395),
#  ('kaepernick', 1.0537054834250288),
#  ('spiritual', -1.0531029646743189),
#  ('perfectly', 1.0530919782171662),
#  ('estimates', -1.0517720320114299),
#  ('resistance', 1.049818106171305),
#  ('larry', 1.0493881249312114),
#  ('citigroup', 1.0465591442166144),
#  ('lowest', 1.0459209827096507),
#  ('67', -1.0458482974470178),
#  ('ufc', -1.0441565111385083),
#  ('uses', 1.043325727786347),
#  ('appoints', 1.0429219220198405),
#  ('propaganda', 1.0416831438128227),
#  ('eclipse', -1.040945858242099),
#  ('solidarity', 1.0409007604808957),
#  ('katrina', 1.038864796036439),
#  ('colleges', 1.0385069869373975),
#  ('crazy', 1.0373801052327578),
#  ('relative', -1.0368745935704018),
#  ('buying', 1.0365279947315587),
#  ('apologizes', 1.035057791039507),
#  ('trailer', -1.034120667328418),
#  ('ignorance', 1.0339183887270662),
#  ('shareholder', 1.0336406845461017),
#  ('homes', 1.033390258612437),
#  ('valley', -1.032336413446902),
#  ('citi', 1.0322736042859522),
#  ('embrace', -1.0317970587564662),
#  ('missed', 1.0314531812249343),
#  ('v.', 1.0305219884126635),
#  ('flooding', -1.0294707582467633),
#  ('verizon', 1.0287470973071156),
#  ('prices', 1.026269821427434),
#  ('laura', 1.023895013390387),
#  ('drunken', -1.0236275219847475),
#  ('surges', 1.0225934731951754),
#  ('suck', 1.020991512235292),
#  ('detective', -1.0188604372614791),
#  ('hong', -1.0186890275329479),
#  ('64', -1.017133887173339),
#  ('smuggling', -1.0164156362613181),
#  ('1st', -1.0150258978243234),
#  ('mexicans', -1.0147576831756002),
#  ('players', 1.0147571138064504),
#  ('dialogue', -1.0127090168150281),
#  ('media', 1.0117710316173603),
#  ('stun', -1.0107272645694327),
#  ('chevron', 1.009531600759909),
#  ('remark', -1.009256045094399),
#  ('wh', -1.0087402295038945),
#  ('guatemala', -1.0077657166219767),
#  ('clarity', -1.0057095355889092),
#  ('h', 1.0055968363995453),
#  ('caterpillar', 1.0049761369340429),
#  ('task', -1.0048200059488857),
#  ('cup', -1.0044552334220245),
#  ('identify', -1.0043653758629791),
#  ('taste', -1.003665202439935),
#  ('perform', -1.0034111596454027),
#  ('southwest', -1.0029384359193472),
#  ('react', -1.0026527072047755),
#  ('linger', -1.0014249012908976),
#  ('countries', 1.0009137675432085),
#  ('fights', 1.0008611322599243),
#  ('exhibit', -1.0003214562250737),
#  ('congo', -1.0000665773920168),
#  ('chef', -0.9995077615211608),
#  ('flee', -0.9989208228065141),
#  ('offers', 0.9982996490761912),
#  ('palestine', 0.9974938707859362),
#  ('aims', 0.99653078609149),
#  ('sentencing', -0.9963200686299608),
#  ('da', -0.9961096741000246),
#  ('rubio', 0.9953414720986308),
#  ('eps', 0.9949419313791587),
#  ('shark', -0.9947883011821111),
#  ('bike', -0.9947232676617147),
#  ('icahn', 0.993510061051601),
#  ('unveils', 0.9934009382593058),
#  ('indict', -0.9932187252806164),
#  ('terrorist', 0.992999767668366),
#  ('filmmaker', -0.992814148879723),
#  ('reid', 0.9927741125271513),
#  ('envoy', -0.9924344158366671),
#  ('warren', 0.9922921649470999),
#  ('apocalypse', 0.9912888587206043),
#  ('mountain', -0.9912543581042069),
#  ('radical', 0.9911554114262252),
#  ('signature', -0.9885380821537695),
#  ('unveil', -0.9882580425640568),
#  ('lab', -0.9871150856013255),
#  ('close', -0.986841441388501),
#  ('fiat', 0.9864388438978758),
#  ('71', -0.9850877713752121),
#  ('denver', -0.9846669673470555),
#  ('fatal', -0.984403439254177),
#  ('sydney', -0.9833419664363198),
#  ('ferguson', 0.9821041447774084),
#  ('republicans', 0.9819758590013858),
#  ('selection', -0.9809288037855004),
#  ('cincinnati', -0.9808393067192425),
#  ('lineup', -0.9807431063694407),
#  ('soccer', -0.9805542533779814),
#  ('beg', 0.9798882443570465),
#  ('launches', 0.9796985353888465),
#  ('72', -0.9795958713431094),
#  ('guidance', 0.97885273879784),
#  ('u.k.', 0.978402494392342),
#  ('nevada', -0.9767302486997009),
#  ('comedy', -0.9747849325691327),
#  ('plenty', -0.9745930245903112),
#  ('63', -0.9744850260086394),
#  ('wire', 0.9740844885918073),
#  ('cambridge', -0.9738159493727887),
#  ('options', 0.973472920520994),
#  ('regional', -0.9732216845062079),
#  ('corp', 0.9731107884219162),
#  ('fatally', -0.9715186230493954),
#  ('liberia', -0.9706320128147544),
#  ('keeps', 0.9704344837477037),
#  ('conspiracy', 0.9685065320357941),
#  ('30-year', -0.9682098383485181),
#  ('standing', 0.9677089616578515),
#  ('atlantic', 0.967598692336279),
#  ('impeach', 0.9658253990939891),
#  ('hopes', 0.9655098702875796),
#  ('vows', 0.9644439067042391),
#  ('factbox', -0.964408953789046),
#  ('journey', -0.963642294402444),
#  ('nonprofit', -0.9617880842563145),
#  ('malaysia', -0.9615771473729601),
#  ('airbus', 0.9604622552038042),
#  ('familiar', -0.9602728824630424),
#  ('accuser', -0.9602175356983834),
#  ('cafe', -0.956445011767829),
#  ('fascist', 0.956345009022715),
#  ('sheet', 0.9563442276643734),
#  ('spit', -0.9556274700619668),
#  ('shin', -0.9552020096518617),
#  ('withdraw', -0.9548400058827706),
#  ('signs', 0.9548113585208899),
#  ('inmate', -0.9547847092358792),
#  ('urge', -0.954679870046405),
#  ('thai', -0.9530921758312457),
#  ('exercise', -0.9501250056643071),
#  ('springs', -0.9500467561383975),
#  ('released', 0.9490688474466281),
#  ('reactor', 0.9480320694596691),
#  ('61', -0.9479187233195988),
#  ('defends', 0.9464076610663928),
#  ('volkswagen', 0.9463442267677182),
#  ('daca', -0.9459381204874587),
#  ('logic', 0.9458962252757936),
#  ('ends', 0.9453271272312678),
#  ('soros', 0.9448940804014206),
#  ('ridiculous', 0.9443932096109733),
#  ('82', -0.9443655209642091),
#  ('bitcoin', -0.943509474797751),
#  ('inaugural', -0.9431635422597932),
#  ('cubs', -0.9420812362629429),
#  ('portfolio', 0.9413310501152645),
#  ('drama', -0.9410664399627291),
#  ('celebration', -0.9409737739532785),
#  ('bolton', 0.9405114208007233),
#  ('shale', -0.9401389011118263),
#  ('artist', -0.9398980578977956),
#  ('millions', 0.9392160436009088),
#  ('crimes', 0.9380511398514402),
#  ('microsoft', 0.9380344472735326),
#  ('nyse', 0.9375875627903072),
#  ('grammy', -0.9371140400324137),
#  ('inspire', -0.9371011731644797),
#  ('condemn', -0.9364995365552189),
#  ('goldman', 0.9354250785879623),
#  ('stance', -0.9352428315656601),
#  ('flaw', -0.9348756822139906),
#  ('actual', 0.9347468502918689),
#  ('ex', -0.9337551749974065),
#  ('photographer', -0.933403091032658),
#  ('viacom', 0.9330905267684257),
#  ('costs', 0.9322664541272526),
#  ('drought', -0.9317141233293611),
#  ('buyout', 0.9316781041307132),
#  ('refinery', 0.9313984008028741),
#  ('detain', -0.9303733938898182),
#  ('matthews', 0.9279512049375838),
#  ('loyalty', 0.9272689236990291),
#  ('examine', -0.9272306648228936),
#  ('snake', -0.9268538447633519),
#  ('taiwan', -0.9266988178975446),
#  ('sells', 0.9264820761711665),
#  ('murphy', -0.9249474667998806),
#  ('opera', -0.9243034603463227),
#  ('stretch', -0.9240324974575326),
#  ('falls', 0.9233036053765141),
#  ('fans', 0.9215027409695897),
#  ('award', -0.9212592753765134),
#  ('tampa', -0.9209255711949988),
#  ('sudan', -0.9191370693309685),
#  ('concerns', 0.9177334944624185),
#  ('depot', 0.9166124883039677),
#  ('q3', 0.9158095465562844),
#  ('reason', 0.9153753782792992),
#  ('rick', 0.9150927551351237),
#  ('freshman', -0.9148200791900177),
#  ('zimmerman', 0.9147743524401419),
#  ('manufacturing', 0.9147606255507138),
#  ('racism', 0.9144172434798189),
#  ('talks', 0.9141991772821716),
#  ('years', 0.9132524793610101),
#  ('discipline', -0.9129036311134149),
#  ('sri', -0.9116536271662445),
#  ('obama', 0.9115962667107154),
#  ('immediately', 0.9114339328970401),
#  ('mccain', 0.9112328915714571),
#  ('o’reilly', 0.9108054649149996),
#  ('screw', 0.910528174151251),
#  ('solutions', 0.9104838124409758),
#  ('analyst', -0.9092264006432399),
#  ('comedian', -0.9092202868680015),
#  ('solo', -0.9090154772917876),
#  ('schools', 0.9086649557500449),
#  ('st.', -0.9084629814843045),
#  ('yellen', 0.9081801117251007),
#  ('dies', 0.9080793069014209),
#  ('ancient', -0.9079282221352908),
#  ('expected', 0.9077992957531686),
#  ('belgium', -0.9075144622160255),
#  ('season', -0.9070088164377766),
#  ('plaza', -0.9055117056281038),
#  ('lawyers', 0.9049954219801123),
#  ('abuse', -0.904944347963433),
#  ('charges', 0.9047597238855443),
#  ('warfare', 0.9042040545672646),
#  ('clash', -0.9037183663288282),
#  ('msm', 0.9032183481206107),
#  ('ted', 0.9031891701688182),
#  ('sprint', 0.9028675289189282),
#  ('hopeful', -0.9020790371865669),
#  ('wto', 0.9011933063958907),
#  ('sky', -0.9008546934344313),
#  ('nepal', -0.9002754152858339),
#  ('irs', 0.8990142272873832),
#  ('cult', 0.898546850733495),
#  ('standards', 0.8983326791780825),
#  ('district', -0.8967400197205495),
#  ('jared', 0.8960589692446115),
#  ('days', 0.8960557733888695),
#  ('nasa', -0.8959388537269733),
#  ('terror', 0.8951520096794785),
#  ('angel', -0.8950424165837937),
#  ('*', 0.8946657643285179),
#  ('mike', 0.8946369356028142),
#  ('hampshire', 0.8944947427835166),
#  ('revise', -0.8941348206478966),
#  ('cfo', 0.8940580692201943),
#  ('speak', -0.8937417631045903),
#  ('alphabet', 0.8936013859516303),
#  ('nominate', -0.8933703963790424),
#  ('area', -0.8933253275020605),
#  ('treasurer', -0.8928208511249084),
#  ('yield', 0.8925248701824954),
#  ('democracy', 0.8923973174739521),
#  ('ukraine', -0.8923015777631135),
#  ('delegation', -0.8919617259350742),
#  ('lgbt', -0.8916822212805067),
#  ('alter', -0.8898653603796837),
#  ('transition', -0.8888982512988216),
#  ('michele', 0.8855888865257969),
#  ('apologiz', -0.8852470221195429),
#  ('mailbag', -0.884914665893619),
#  ('buyback', 0.8846599014876501),
#  ('establishment', 0.8838052422221704),
#  ('stability', -0.8821161044771961),
#  ...]

# %%
# test on own train set just to see
test_on_train = model(lr, count_uni, x_train, y_train, x_train, y_train)
# Out:
# [LibLinear]accuracy: 77.71%

# %%
# test on other sample of training set
test_train = pd.read_csv('data/train_df_spacy1.csv').sample(frac=.1, random_state=1)
y_test_train = test_train['label']
x_test_train = test_train['text_lemmas']
test_on_other_train = model(lr, count_uni, x_train, y_train, x_test_train, y_test_train)
# Out:
# [LibLinear]accuracy: 75.49%

# %% [markdown]
# # pre-vocab-cut with TFIDF instead of count

# %%
lr_tfidf_uni = model(lr, tfidf_uni, x_train, y_train, x_test, y_test)
# Out:
# [LibLinear]accuracy: 58.46%

# %%
lr_tfidf_uni
# Out:
# [('globalpost', -15.209367484290894),
#  ('advertisement', -13.980293089637476),
#  ('—', 11.26303306996885),
#  ('albuquerque', -10.963246458902262),
#  (' ', 9.344577484072838),
#  ('say', -9.152463455789329),
#  ('mr.', 6.271199251298934),
#  ('mexico', -6.0622505930501696),
#  ('nyse', 5.950101456753023),
#  ('baptist', -5.74739112840326),
#  ('\u200a', 5.693008391410383),
#  ('%', 5.684710325103299),
#  ('principles', -5.229156455902334),
#  ('fe', -5.091643546829893),
#  ('/', 4.928437576947869),
#  ('blade', -4.918727977089896),
#  ('fusion', -4.855452429678226),
#  ('ap', -4.8115759118369),
#  ('fool', 4.714885364305213),
#  ('--', -4.624555091041627),
#  ('standards', -4.488040821508517),
#  ('motley', 4.454509496770389),
#  ('2017', -4.4181035605464976),
#  ('…', 4.405356234723576),
#  ('california', -4.256611394040326),
#  ('fox', 4.209820802144774),
#  ('ethics', -4.2093115396258),
#  ('reuters', -4.051947493167888),
#  ('hillary', 3.9392980580087786),
#  ('season', -3.936277075979115),
#  ('click', 3.870803994261502),
#  ("buy'sell", -3.7928624636312525),
#  ('bush', 3.7576225215018564),
#  ('associated', -3.746794998798281),
#  ('source', 3.720904299244263),
#  ('journal', -3.642937392470697),
#  ('performer', -3.6356727745720097),
#  ('media', -3.6338660352014536),
#  ('apparently', 3.6003239714953046),
#  ('estimated', -3.5200932979160564),
#  ('embed', -3.44948847528813),
#  ('new mexico', -3.4462158534536282),
#  ('wire', 3.444180498849629),
#  ('!', 3.4065074470417605),
#  ('santa', -3.3348649166004978),
#  ('watch', 3.2652113964520915),
#  ('reliance', -3.2505278353795872),
#  ('unm', -3.2035625106791774),
#  ('0', -3.1428259116735613),
#  ('risky', -3.132243869075926),
#  ('mr', 3.124816490354828),
#  ('�', 3.0961395050021583),
#  ('quote', -3.073748860184237),
#  ('q', -3.0650520847807075),
#  ('nasdaq', 3.064159589319476),
#  ('continue', 3.0446360507704777),
#  ('rio', -3.0421188360469333),
#  ('cps', -3.035068686585889),
#  ('church', -3.0272935426237293),
#  ('lgbt', -2.9994110561972778),
#  ('corporate', 2.950532464072966),
#  ('write', -2.949371014408007),
#  ('lottery', -2.9375397250888273),
#  ('feminist', 2.9111943990595317),
#  ('photo', -2.8997466569540347),
#  ('update', 2.895764016100388),
#  ('wing', 2.88253311039002),
#  ('dear', -2.8733218673810357),
#  ('leftist', 2.864887222104711),
#  ('rancho', -2.847888022416699),
#  ('sacramento', -2.841625731999075),
#  ('ms.', 2.8220450547330627),
#  ('drawing', -2.8101759065069687),
#  ('author', 2.782699195236947),
#  ('january', -2.7757466327172295),
#  ('priest', -2.768627332300287),
#  ('originally', 2.728237017309328),
#  ('old', -2.715686542179705),
#  (':', 2.711507176211509),
#  ('guardian', 2.709917582259402),
#  ('16', -2.660855726688528),
#  ('left', 2.6437071980714766),
#  ('share', 2.6346855726027774),
#  ('.', -2.6009035900960673),
#  ('liability', -2.590146754014579),
#  ('basis', 2.5787477117300077),
#  ('company', 2.5652839476987976),
#  ('occupation', 2.55202952632995),
#  ('progressive', 2.5460512730932714),
#  ('palin', 2.544803297316636),
#  ('newspaper', -2.5245677383885985),
#  ('_', -2.521085807368593),
#  ('militant', -2.476368927806704),
#  ('debut', -2.4660848437579497),
#  ('advisor', 2.4611710773037108),
#  ('beast', 2.458006994904855),
#  ('capitalism', 2.4419772854014337),
#  ("'s", 2.4226802712492845),
#  ('terror', 2.4047251055140264),
#  ('propaganda', 2.4040334784852093),
#  ('counterpunch', 2.3973066643955194),
#  ('corp.', 2.3858669510156285),
#  ('trust', -2.3829293041664137),
#  ('fact', 2.3612671536969922),
#  ('gmt', 2.3582591890936726),
#  ('myanmar', -2.3449683459461714),
#  ('tour', -2.3333279164200174),
#  ('right', 2.329664903074411),
#  ('reed', 2.3227161074201748),
#  ('?', 2.295835407441276),
#  ('link', 2.2875529291332963),
#  ('wall', 2.2866789538426615),
#  ('corn', 2.2632171876653513),
#  ('product', 2.2603026049005965),
#  ('play', -2.258850608490298),
#  ('chart', -2.2513369292956167),
#  ('editor', -2.2458806233279707),
#  ('jackpot', -2.2439251273796677),
#  ('permission', 2.22649299751647),
#  ('thomson', -2.1971907873783136),
#  ('expect', 2.1948858795654376),
#  ('investor', 2.1772208954117547),
#  ('marine', 2.1620395043812417),
#  ('ministry', -2.152207196705156),
#  ('etf', 2.1517701014669326),
#  ('saturday', -2.13515944541272),
#  ('demand', 2.1293344015735887),
#  ('matter', 2.1236842000329146),
#  ('senator', 2.116941272869037),
#  ('cheney', 2.1141091622008417),
#  ('martinez', -2.114054922392011),
#  ('mention', 2.1067117005769807),
#  ('2018', -2.0976046842555274),
#  ('’s', -2.086944922296115),
#  ('forecast', 2.0844062510688746),
#  ('prisoner', 2.0822447509502093),
#  ('alexander', 2.0819044668399016),
#  ('clip', 2.0780529020340746),
#  ('web', 2.073348215967666),
#  ('december', -2.068876528733189),
#  ('iraq', 2.068007624839139),
#  ('include', -2.0633838402374227),
#  ('winter', -2.0567932324957208),
#  ('serve', -2.054548224267976),
#  ('explain', 2.0485015188871607),
#  ('baptists', -2.0483676711260745),
#  ('u.k.', 2.039393837027639),
#  ('document', 2.0312906140198703),
#  ('13', -2.026548295407344),
#  ('israel', 2.0180791532815467),
#  ('19', -2.009078739961038),
#  ('narrative', 2.001886600370939),
#  ('customer', 1.9998607033125582),
#  ('bernalillo', -1.991104164263778),
#  ('war', 1.990426575780433),
#  ('image', 1.988803519037764),
#  ('actually', 1.9790984440775734),
#  ('movement', 1.9737031104459715),
#  ('new', -1.9721245519689952),
#  ('different', -1.9677884704563622),
#  ('mother', 1.95800822524638),
#  ('washington', -1.9511564767920766),
#  ('artist', -1.9485184660836805),
#  ('‘', 1.9484314525464008),
#  ('accuse', -1.9474672381764053),
#  ('hell', 1.9469340895822524),
#  ('lie', 1.9452540768421966),
#  ('cruces', -1.938806676127495),
#  ('credit', 1.9383876314752309),
#  ('india', -1.9360596034435198),
#  ('deputy', -1.9359646160681028),
#  ('black', 1.9350792799403587),
#  ('casino', 1.9332615717944959),
#  ('climate', 1.9305170665426663),
#  ('poverty', 1.9292601674248921),
#  ('tv', -1.926938596159656),
#  ('rape', 1.9241234997908596),
#  ('fully', -1.9193170043106762),
#  ('southeast', -1.916256401984221),
#  ('performance', -1.9156221392078026),
#  ('32', -1.9073088894401273),
#  ('okay', 1.9063558056364214),
#  ('copyright', 1.8999291616386917),
#  ('phoenix', -1.8992675378438577),
#  ('piece', 1.8966278482100518),
#  ('terrorist', 1.8920152154264511),
#  ('caller', 1.8913579819636512),
#  ('insider', -1.8897128033045636),
#  ('ted', 1.8879275737959083),
#  ('tariff', -1.8850802910095164),
#  ('marco', -1.8843357072435045),
#  ('innocent', 1.8810048008967835),
#  ('instagram', -1.8784538795466819),
#  ('msnbc', 1.8765767136764917),
#  ('shooter', 1.8764730755619992),
#  ('surgery', -1.8715613681435097),
#  ('signal', -1.871137436927974),
#  ('23', -1.8685597316840221),
#  ('assert', 1.8627921643508802),
#  ('fellow', -1.8596662203312064),
#  ('industry', 1.8580943113835455),
#  ('mexican', 1.853271649847058),
#  ('citizens', 1.8511601846511814),
#  ('corp', 1.8503174434784018),
#  ('opinion', -1.8490476140064478),
#  ('capitalist', 1.8420340197874594),
#  ('[', 1.8387694540977015),
#  ('pm', 1.8383716051856198),
#  ('anti', 1.827621886234644),
#  ('partisan', -1.8234593508874564),
#  ('announce', -1.8186020228719741),
#  ('paper', -1.8183008685087816),
#  ('york', 1.8160300894246566),
#  ('drama', -1.814699880502545),
#  ('page', 1.8137875810874085),
#  ('   ', -1.8122062638979348),
#  ('racist', 1.810963496667702),
#  ('character', -1.8108956476757054),
#  ('golden', -1.8103945678185915),
#  ('fraud', 1.8038571550272688),
#  ('kenya', -1.80202753539144),
#  ('liberal', 1.8013115023716955),
#  ('enact', -1.7998148336535906),
#  ('publish', -1.7937959567387165),
#  ('business', 1.7936013790713303),
#  ('sample', -1.7930360695951193),
#  ('slash', 1.792568344863339),
#  ('radical', 1.7915172419533612),
#  ('note', 1.7886377372914148),
#  ('billion', 1.7836145458297514),
#  ('bp', 1.7806423032247143),
#  ('centre', 1.7778724743092826),
#  ('period', 1.7765245187726604),
#  ('likely', 1.7754743288323065),
#  ('coach', -1.7652646033716863),
#  ('councilor', -1.7647747257702795),
#  ('claim', 1.7640568573146553),
#  ('monetary', 1.7600045177324348),
#  ('flag', 1.7519562674392104),
#  ('elite', 1.7481674456541791),
#  ('(', -1.7438792514100427),
#  ('file', -1.7432999537327165),
#  ('white', 1.7402469531529718),
#  ('song', -1.7398215696296238),
#  ('shall', 1.7379271131078804),
#  ('refuse', 1.7367267597325264),
#  ('entrepreneur', 1.7313337501860686),
#  ('outrage', 1.7256599399120578),
#  ('time', -1.724710023980554),
#  ('objective', 1.7238944608930495),
#  ('wealthy', 1.7212847997130891),
#  ('congregation', -1.715019094227579),
#  ('steve', -1.7131545801593766),
#  ('crimea', -1.705520232643882),
#  ('center', -1.7023250468454623),
#  ('lgbtq', -1.6978617674636325),
#  ('husband', -1.6970459457666691),
#  ('apd', -1.6906910175202408),
#  ('evangelical', -1.6904237765881582),
#  ('bipartisan', -1.6814701188772978),
#  ('navajo', -1.6789796165751896),
#  ('related', -1.6776758988058587),
#  ('mission', -1.6751699833161722),
#  ('entitlement', -1.674629102104548),
#  ('american', 1.6745594173106022),
#  ('sandia', -1.673057194127096),
#  ('expose', 1.6725379991377667),
#  ('percent', -1.6719089707355927),
#  ('2nd', 1.6701925772943786),
#  ('sister', -1.6660564817520644),
#  ('delegate', 1.6656153636403954),
#  ('ii', -1.6643545266873763),
#  ('labor', 1.6643365270928157),
#  ('resistance', 1.6641921951062888),
#  ('mainstream', 1.6638151937381165),
#  ('democracy', 1.6611602258851517),
#  ('–', -1.658320976981092),
#  ('cook', -1.655979039466396),
#  ('similar', -1.6528677764348978),
#  ('ton', 1.6488033997631155),
#  ('thank', 1.643400262424649),
#  ('course', 1.6417832996025274),
#  ('•', -1.6417060851504242),
#  ('payer', 1.6395321311809998),
#  ('online', -1.639038401718511),
#  ('tip', 1.6367625316396337),
#  ('illegal', 1.6354234426138134),
#  ('log', 1.6318856749030517),
#  ('anchor', -1.6305399956952162),
#  ('tell', -1.629053207503729),
#  ('brown', -1.6268415015780728),
#  ('imf', 1.621359370553927),
#  ('attorney', -1.6198131474699498),
#  ('survey', 1.6193423345473406),
#  ('voting', 1.618167839598156),
#  ('world', -1.6175536667223214),
#  ('daily', 1.6140650095715483),
#  ('americans', 1.61214075991598),
#  ('activist', 1.6078248429576736),
#  ('asset', 1.6023781097537722),
#  ('justice', 1.60177666120365),
#  ('racism', 1.6013223323812527),
#  ('goal', -1.5990888562494094),
#  ('colorado', -1.5942233246847684),
#  ('alaska', 1.5915467312948153),
#  ('abortion', 1.5895526113764562),
#  ('isis', 1.5893337851864469),
#  ('socialist', 1.5892596706082842),
#  ('...', -1.5859740022969926),
#  ('exactly', 1.5848181378282504),
#  ('giant', 1.5821829116764072),
#  ('friendly', 1.5803042233487776),
#  ('sex', 1.5789811478890212),
#  ('help', -1.5787406119678533),
#  ('cent', 1.578732609777777),
#  ('yard', -1.5772003661450908),
#  ('neoliberal', 1.5762470983962382),
#  ('herald', -1.5746055430624621),
#  ('strategy', 1.5741672964952282),
#  ('riot', 1.572754548124833),
#  ('seminary', -1.570607757920782),
#  ('6', -1.5674594613539914),
#  ('fargo', -1.565372173241949),
#  ('damage', -1.564827791934965),
#  ('jones', 1.564556686820944),
#  ('diego', -1.5634042721876864),
#  ('order', 1.55221326986843),
#  ('employee', 1.5510279682686068),
#  ('homosexuality', 1.548818238912004),
#  ('nfl', 1.5468666378323799),
#  ('austin', -1.5455783669804926),
#  ('warren', 1.5448940330294643),
#  ('traffic', -1.5414870308833315),
#  ('southwest', -1.5393559364985037),
#  ('deep', -1.53908105663253),
#  ('gun', 1.5389309043806318),
#  ('thailand', -1.5361475089662389),
#  ('tea', 1.5355177839181025),
#  ('possible', -1.535217313843095),
#  ('aca', -1.5337914866080296),
#  ('florida', 1.533599422854917),
#  ('plc', 1.5319531632419086),
#  ('estimate', -1.5313125741533726),
#  ('touchdown', -1.5263563828103945),
#  ('comey', 1.520784139787985),
#  ('label', -1.5205682159264426),
#  ('grain', 1.520332971646219),
#  ('relative', -1.5176323263494775),
#  ('infamous', 1.5115651562845667),
#  ('publisher', -1.5104473723306684),
#  ('high', -1.510230765761088),
#  ('cattle', 1.5101713487972273),
#  ('motors', 1.5076193430516152),
#  ('pundit', 1.506159289999854),
#  ('rubio', 1.4978493386010954),
#  ('difficult', -1.4942919024898926),
#  ('staffer', 1.488843722564231),
#  ('finally', 1.4887254407266481),
#  ('maintain', 1.4885080573617662),
#  ('output', 1.4884540679353329),
#  ('assembly', -1.48611268114909),
#  ('syria', -1.4853510275659592),
#  ('politico', 1.482529128968526),
#  ('disclosure', 1.4817169227500389),
#  ('abuse', -1.4807807437070386),
#  ('11', -1.4778554243689426),
#  ('ipad', 1.475651994491212),
#  ('moderate', -1.4735204511998952),
#  ('obama', 1.4727329526418629),
#  ('recall', 1.4698558449403964),
#  ('stand', 1.4691706044813282),
#  ('mass', 1.46879226676785),
#  ('intellectual', 1.46619395077602),
#  ('roughly', 1.4648632546280795),
#  ('100', 1.462868606177272),
#  ('shareholder', 1.4628203647155333),
#  ('film', -1.4620527537510617),
#  ('pro', 1.4605173523051147),
#  ('listen', 1.459025786521513),
#  ('experiment', -1.4582664550230475),
#  ('cop', 1.4580401755786374),
#  ('gov.', -1.457022649009597),
#  ('childhood', -1.4557831401609926),
#  ('spill', 1.4535089601508735),
#  ('anthem', 1.4501506162287816),
#  ('getty', 1.450114215705628),
#  ('carson', 1.4501112564437093),
#  ('environmental', 1.4483528983097866),
#  ('title', -1.4444322458731782),
#  ('=', 1.4440059886646728),
#  ('merely', 1.443702768775376),
#  ('shut', 1.4430401470506744),
#  ('path', -1.4422574957335965),
#  ('12', -1.440782114417389),
#  ('edit', 1.4398558858041612),
#  ('consumer', 1.4394338502223123),
#  ('small', 1.4380049529778691),
#  ('inc.', 1.4377206819147843),
#  ('mph', -1.4368592746551991),
#  ('ranking', -1.4358430551037027),
#  ('15', -1.4357971001342809),
#  ('bee', -1.4353477015877518),
#  ('punishment', 1.434157918012419),
#  ('information', -1.433727405092042),
#  ('host', 1.4315892137703163),
#  ('u.s.', 1.4299300890261204),
#  ('bishop', -1.4282741713863025),
#  ('analysis', -1.4281378209760014),
#  ('*', 1.4277058074837092),
#  ('military', 1.4275990704320551),
#  ('like', 1.427066349425356),
#  ('social', 1.424937898831119),
#  ('debt', 1.4247897586713),
#  ('decide', 1.4236053004076794),
#  ('capability', -1.42236564772465),
#  ('organize', 1.4222422824836924),
#  (')', 1.4117429201529146),
#  ('suspend', -1.411673390120666),
#  ('pope', 1.410271451245299),
#  ('ad', -1.407934512359259),
#  ('legislative', -1.4078147746784122),
#  ('-pron-', 1.4075829402258202),
#  ('secret', 1.4061393985481576),
#  ('hire', 1.4037936284860713),
#  ('unfortunately', 1.4029376136624896),
#  ('executive', 1.402748409266724),
#  ('south', -1.4002842464111152),
#  ('catholic', -1.399421925021024),
#  ('leader', -1.3985083727254086),
#  ('brand', 1.394072397248978),
#  ('medium', 1.3933698130692227),
#  ('lead', -1.390023827950625),
#  ('administration', 1.3896729165942343),
#  ('worldwide', -1.3894139698754673),
#  ('save', 1.387815079608995),
#  ('pew', -1.3866744398778084),
#  ('ok', -1.3853490923523195),
#  ('clock', -1.3845174825059807),
#  ('occupy', 1.3801096980165195),
#  ('hollywood', 1.379261000336471),
#  ('attempt', 1.3782501264991638),
#  ('join', 1.3726429276700096),
#  ('signature', -1.371294379518339),
#  ('maker', 1.3704951841176798),
#  ('dallas', -1.3698875831781883),
#  ('despite', 1.3695406093915987),
#  ('game', -1.3693176233976434),
#  ('suggest', 1.3688128157726662),
#  ('convict', -1.3682529018395448),
#  ('nevada', -1.3655749597416276),
#  ('cia', 1.3651757325240597),
#  ('plant', 1.3643338418030853),
#  ('financial', 1.3640291678588459),
#  ('school', -1.3609873741048812),
#  ('additionally', 1.360497574885834),
#  ('21st', 1.357570505092479),
#  ('comic', -1.356849205483002),
#  ('director', -1.3565560434096418),
#  ('samsung', 1.3564444512363805),
#  ('bernie', 1.350679931659832),
#  ('epa', 1.3503656976368388),
#  ('remember', 1.350319237674452),
#  ('prior', 1.348267730305273),
#  ('leave', -1.347138227039746),
#  ('ask', 1.346475613813796),
#  ('salary', -1.3452780167357552),
#  ('pension', -1.3446716830279726),
#  ('hold', -1.3425317873353315),
#  ('segment', 1.3418893376035004),
#  ('column', -1.3417249048971622),
#  ('chronicle', -1.3409941586133138),
#  ('associate', -1.340971492835391),
#  ('dump', 1.3398347031163969),
#  ('completely', 1.3381219758537346),
#  ('collective', 1.3368995563172186),
#  ('base', 1.3364221963439822),
#  ('yesterday', 1.3352992108793178),
#  ('boycott', 1.3347842312682652),
#  ('comply', 1.3332041684175744),
#  ('camera', -1.3318107848122576),
#  ('benghazi', 1.3308692228439993),
#  ('caucus', 1.3307467003062867),
#  ('unit', 1.3298148866967257),
#  ('poll', 1.3284304282861736),
#  ('cut', 1.3252314252223196),
#  ('courtesy', -1.3249020756636851),
#  ('shia', 1.3245208473047085),
#  ('kelly', 1.321862977454094),
#  ('cruz', 1.3173540737936642),
#  ('furthermore', 1.3170381539758753),
#  ('lot', -1.316017643873143),
#  ('las', -1.314732046323068),
#  ('industrial', 1.3087501262387167),
#  ('concern', -1.3063879543078307),
#  ('weekly', -1.306264323416809),
#  ('multiple', 1.306117903694751),
#  ('20th', -1.3055053524173736),
#  ('banking', 1.3042834144096545),
#  ('journalism', -1.3032254823107412),
#  ('homosexual', 1.3008054978117356),
#  ('america', 1.2994237348109832),
#  ('establishment', 1.29547244846134),
#  ('recommend', 1.2930370558862934),
#  ('42', -1.2925813478486015),
#  ('chief', 1.2922725603093825),
#  ('thousand', 1.2906642384329527),
#  ('settle', 1.2905351490071484),
#  ('lisa', -1.2892882464428546),
#  ('shape', -1.2867509958535364),
#  ('conflict', -1.285679286169848),
#  ('torture', 1.2848971211183873),
#  ('risk', -1.2844022723110329),
#  ('“', 1.2830354228898337),
#  ('voter', -1.2820168871922244),
#  ('catholics', -1.2797182823179976),
#  ('difference', -1.279414303318851),
#  ('forward', -1.2793403136023622),
#  ('hurricane', 1.2789261894344914),
#  ('extremist', -1.2781518792016349),
#  ('cleveland', -1.278043615585426),
#  ('reject', 1.277807112669523),
#  ('threaten', 1.2768667397973072),
#  ('shopper', 1.2767368729439625),
#  ('jonathan', -1.2764309932962068),
#  ('nader', 1.275323843557369),
#  ('profitable', 1.2747154476609077),
#  ('memo', 1.2728073811590175),
#  ('bbc', 1.2724079996033089),
#  ('bitcoin', -1.2719643629400166),
#  ('mitchell', -1.270473159111638),
#  ('pat', 1.2701378486296493),
#  ('bet', 1.268960667111612),
#  ('bomb', 1.26876852088039),
#  ('yahoo', 1.2677273255633381),
#  ('indonesia', -1.2667949095542206),
#  ('rumsfeld', 1.265678566400534),
#  ('clear', 1.2645423169576273),
#  ('jews', 1.2641443932632275),
#  ('newsletter', 1.2640623507124324),
#  ('workers', 1.2636400182742784),
#  ('yen', -1.262751637585177),
#  ('ukraine', -1.2617633487413147),
#  ('modern', -1.25951750118243),
#  ('town', -1.257772296185796),
#  ('mock', 1.2576554597668834),
#  ('content', -1.256522975055674),
#  ('conspiracy', 1.256501122206778),
#  ('limbaugh', 1.2558766758465025),
#  ('student', 1.2551888006926417),
#  ('prosecutor', -1.2545265864466602),
#  ('assault', 1.25405902745345),
#  ('17', -1.2537825930118298),
#  ('slideshow', -1.2537025876483168),
#  ('creator', -1.2536198915797379),
#  ('turkey', -1.2528045260522038),
#  ('profit', 1.2525788486139586),
#  ('expectation', 1.2514912731742582),
#  ('slaughter', 1.2508558960523968),
#  ('karl', 1.2488767200379762),
#  ('kilometer', -1.248452518663588),
#  ('accord', -1.247680283524455),
#  ('revolution', 1.2476329732059865),
#  ('nbc', -1.246570086791465),
#  ('achievement', -1.2456244137606844),
#  ('marketing', 1.2446551913043034),
#  ('stupid', 1.2444397423769653),
#  ('ukrainian', -1.2439701021579919),
#  ('costly', -1.2412075618941196),
#  ('following', 1.2386772763691722),
#  ('star', -1.2385086465935031),
#  ('parliament', -1.2380794601783516),
#  ('cardinal', -1.236456312445154),
#  ('journey', -1.2345346660936205),
#  ('francisco', 1.2340172564946748),
#  ('lobos', -1.233286208352328),
#  ('telephone', -1.2313207119580596),
#  ('manufacturing', 1.2303106129598587),
#  ('bar', -1.2294125160646443),
#  ('dirty', 1.2280235123688281),
#  ('scientist', -1.2258041203347019),
#  ('fed', 1.2246993612557426),
#  ('catalyst', -1.2246956655732502),
#  ('boy', 1.2235613700859604),
#  ('designer', -1.222253709274409),
#  ('prove', 1.222237644367733),
#  ('book', 1.2220360298426325),
#  ('dance', -1.2218988597835865),
#  ('separation', 1.2210269033616907),
#  ('seek', -1.22038987015852),
#  ('real', 1.2203007497450962),
#  ('draw', -1.2202525442636598),
#  ('richmond', -1.2182785275972503),
#  ('14', -1.2177658605838566),
#  ('proposition', -1.2176373958456694),
#  ('deduction', 1.217021612008792),
#  ('developer', 1.2165035035482932),
#  ('revise', 1.2151569048687991),
#  ('compare', 1.2151536322952612),
#  ('romero', -1.2151533885094346),
#  ('recognize', -1.2144237848463368),
#  ('inside', -1.2135861826784589),
#  ('studio', -1.212162013145855),
#  ('conceal', 1.2106724711274772),
#  ('4', -1.2098875530196644),
#  ('ceremony', -1.2090651117520343),
#  ('arnold', -1.2080536737112904),
#  ('finish', -1.2070783869778088),
#  ('cheese', -1.204255646090914),
#  ('24', -1.2034481072852414),
#  ('outlook', 1.203365507271262),
#  ('3', -1.2015176010537294),
#  ('respond', 1.201418196691462),
#  ('reliable', -1.201050384383276),
#  ('little', 1.2004050990273183),
#  ('chairman', 1.2002737904118224),
#  ('democrats', 1.2001148472436054),
#  ('7', -1.1999895749871057),
#  ('approximately', 1.1998219374471508),
#  ('jerry', -1.199291041170169),
#  ('gospel', -1.1988871191147097),
#  ('flat', 1.1964068255687947),
#  ('cuomo', 1.1960421704262167),
#  ('saving', 1.195596030699671),
#  ('rice', 1.1943204220080879),
#  ('prospect', 1.1936173529400917),
#  ('monitor', -1.1935123427423076),
#  ('scandal', 1.19220240971314),
#  ('county', -1.1917692233404127),
#  ('sanctuary', 1.1912194858178853),
#  ('variety', -1.1904696791615437),
#  ('evidence', 1.1900615102825827),
#  ('principal', -1.1886116205830433),
#  ('popular', 1.188281280893636),
#  ('lucky', -1.1880628908876687),
#  ('authority', -1.187578416330129),
#  ('camp', 1.1856228667727666),
#  ('palestine', 1.1848163983574997),
#  ('columnist', -1.1845965033097179),
#  ('retirement', 1.1835445638968967),
#  ('homeland', 1.183383391439466),
#  ('description', 1.1830426709997426),
#  ('appear', 1.1812024017289955),
#  ('program', -1.180285916290105),
#  ('$', 1.1802185203208042),
#  ('r', 1.177662350349287),
#  ('automaker', 1.177271960840597),
#  ('muslim', 1.17661537598375),
#  ('guarantee', 1.1764808961886186),
#  ('campaign', 1.175961598709708),
#  ('commerce', 1.1750130522883877),
#  ('seven', -1.174910683695762),
#  ('market', 1.1740902012111905),
#  ('discount', 1.1737223509180856),
#  ('buyer', -1.17254128808292),
#  ('example', 1.1718173575364446),
#  ('beat', 1.169767065790454),
#  ('trick', 1.1678126523532952),
#  ('consider', 1.1677798572550098),
#  ('rebel', -1.166941057696507),
#  ('irs', 1.1637171265435),
#  ('spokesperson', 1.1635826106898042),
#  ('russian', -1.1625208585589069),
#  ('contain', -1.1618296988606698),
#  ('yeah', 1.1599718507295471),
#  ('creative', 1.1594160417036496),
#  ('sandoval', -1.1577880240999319),
#  ('love', -1.157163226956046),
#  ('certify', -1.156729160326454),
#  ('advice', 1.1563992448404434),
#  ('pelosi', 1.1560859377355417),
#  ('invest', 1.154972935982073),
#  ('inequality', 1.153308084152028),
#  ('slip', -1.1530870696585847),
#  ('simply', 1.1515701421318276),
#  ('blow', 1.1514833376865623),
#  ('theological', -1.1491297378128724),
#  ('knowledge', 1.1491101080806714),
#  ('empire', 1.1476088548866907),
#  ('cartoon', 1.1473415789755146),
#  ('20', -1.1465925948696376),
#  ('revenue', 1.1450358942422938),
#  ('tokyo', -1.144400153006466),
#  ('museum', -1.142548712325509),
#  ('illinois', -1.1419530764515768),
#  ('people', 1.1417522388153343),
#  ('sentence', -1.1411464518174592),
#  ('2006', 1.1406843340716069),
#  ('genius', 1.1404418742710558),
#  ('gingrich', 1.140248214452685),
#  ('rise', 1.139198977418701),
#  ('original', 1.1389863632509152),
#  ('bike', -1.1386731614545977),
#  ('reader', -1.1379429491970128),
#  ('bias', 1.1364736795798245),
#  ('roman', -1.1348108885375583),
#  ('58', -1.1347404712635483),
#  ('nba', 1.1342505304522328),
#  ('corporation', 1.1334858662847758),
#  ('defensive', -1.1330845720329759),
#  ('sick', 1.132307595969965),
#  ('rig', 1.1313069108339149),
#  ('away', -1.1308571413810955),
#  ('invade', 1.13041677509693),
#  ('patent', 1.129798518738426),
#  ('tactic', 1.1276541420322452),
#  (',', 1.1273780621386016),
#  ('dc', 1.127249650159728),
#  ('close', -1.1243844806492072),
#  ('operating', 1.1243051465464318),
#  ('week', 1.124143158606642),
#  ('el', -1.1235037033893296),
#  ('analyst', -1.1232209149890526),
#  ('website', -1.1191467753232431),
#  ('kick', 1.118822558588613),
#  ('69', -1.1178573129248732),
#  ('series', -1.1176933563046845),
#  ('globe', -1.1168847119112848),
#  ('foreclosure', 1.115137722790915),
#  ('72', -1.113856656615968),
#  ('mexicans', -1.1129599753302601),
#  ('inform', -1.112082486997116),
#  ('allow', -1.111717598955521),
#  ('seed', -1.1116102739674885),
#  ('richard', -1.11143566736946),
#  ('enforcement', 1.111318248768031),
#  ('editing', 1.1110104716977547),
#  ('43', -1.1096556025982478),
#  ('bully', 1.1081701291327821),
#  ('cite', -1.1081359047928925),
#  ('prince', 1.10757726084096),
#  ('reason', 1.106492871416681),
#  ('rachel', 1.1057824299437156),
#  ('producer', 1.1055547391511815),
#  ('presumably', 1.1054835470372883),
#  ('hearing', -1.1051522166699432),
#  ('asian', -1.1033430000183524),
#  ('pentagon', 1.1032611956818028),
#  ('alamos', -1.1024936621832473),
#  ('pot', -1.1022220690569358),
#  ('double', -1.1021906998707998),
#  ('teaching', -1.1021018681059827),
#  ('taste', -1.1019807374420145),
#  ('pose', 1.1019164260047454),
#  ('terrible', 1.1017939084207697),
#  ('8', -1.1014508218766443),
#  ('volatility', -1.100717698946419),
#  ('bank', 1.1007057268250418),
#  ('chris', 1.1005430587985467),
#  ('boeing', 1.0989914312828253),
#  ('money', 1.0985001589644399),
#  ('working', 1.098061195051172),
#  ('report', -1.0958222090079797),
#  ('mean', 1.0948275942930028),
#  ('area', -1.094478404241774),
#  ('contribute', -1.0934527095700544),
#  ('fighting', -1.092314729676596),
#  ('berkeley', 1.0922736565169977),
#  ('taylor', -1.0912656439858615),
#  ('trump', 1.090958593589715),
#  ('’', 1.0895926089872268),
#  ('moment', -1.0891067054659929),
#  ('management', 1.0887816955857295),
#  ('barry', -1.088059407639691),
#  ('guilty', -1.0880534739465537),
#  ('create', -1.0871638776614718),
#  ('promote', 1.085861214662205),
#  ('explicitly', 1.0854508538562344),
#  ('putin', 1.0840928184337946),
#  ('clearly', 1.0835632316768844),
#  ('schedule', -1.0831797712377202),
#  ('worship', -1.0817277509325751),
#  ('pretty', 1.0803584499138104),
#  ('juror', -1.079334819218785),
#  ('regret', 1.0786589737206604),
#  ('compete', -1.0783594058223724),
#  ('directly', 1.0767236659214008),
#  ('pueblo', -1.0758404510600124),
#  ('colonial', 1.0754736066255433),
#  ('dissent', 1.0753903406088252),
#  ('embrace', -1.0750438655111705),
#  ('ambassador', -1.0749548209331505),
#  ('jump', 1.0747391511568158),
#  ('response', 1.07417351830783),
#  ('vet', 1.073892958930688),
#  ('biotech', 1.0734524402853394),
#  ('hernandez', -1.0732931568238435),
#  ('reception', -1.0729136119117677),
#  ('hot', 1.0723841724768572),
#  ('available', 1.0715364762733675),
#  ('civilization', 1.0713685810233553),
#  ('denver', -1.0712756523801208),
#  ('similarly', 1.0711714724165842),
#  ('amendment', 1.0706254692454331),
#  ('petroleum', 1.070526649027883),
#  ('2014', -1.069134013811888),
#  ('rip', 1.0687357321246413),
#  ('literally', 1.067576479182594),
#  ('donor', 1.067318103315376),
#  ('use', -1.0669613159419034),
#  ('grace', -1.0667254081888127),
#  ('metric', 1.0657530201528773),
#  ('attack', 1.065231584688633),
#  ('comment', 1.0648600029391515),
#  ('boston', -1.0646404160359855),
#  ('spouse', 1.0644107234954752),
#  ('prepared', 1.0626858702463076),
#  ('troy', -1.061493559721924),
#  ('sunday', -1.0613155507969003),
#  ('stress', -1.060594295463595),
#  ('prison', 1.0600760016770785),
#  ('overseas', -1.0598620857808707),
#  ('snow', -1.0596468537114143),
#  ('lecture', 1.059518357540151),
#  ('israeli', 1.059308344506798),
#  ('gdp', -1.058026313138582),
#  ('tragic', 1.0575265462973018),
#  ('moore', 1.0573985290283727),
#  ('price', 1.0561422243534133),
#  ('class', 1.0548238246980453),
#  ('chase', -1.054609382767609),
#  ('shopping', 1.0545245767569371),
#  ('constitution', 1.0541947883018747),
#  ('metro', -1.0541819313426457),
#  ('faith', -1.0531824704685406),
#  ('finger', 1.0525988215895836),
#  ('imply', 1.0512638477537688),
#  ('facility', 1.0510126150001158),
#  ('elementary', -1.0508270573366234),
#  ('long', 1.0505775665492996),
#  ('membership', 1.049464593500511),
#  ('lobby', 1.0493778157746845),
#  ('civilian', 1.0492883028295),
#  ('represent', -1.0482245674928223),
#  ('twin', -1.0477517271494805),
#  ('spark', -1.046994513305485),
#  ('prompt', -1.0454201217442913),
#  ('mega', -1.0451540485649196),
#  ('verizon', 1.0447964161533387),
#  ('buy', 1.0446239014970484),
#  ('foods', 1.0442642158670508),
#  ('ignorance', 1.043352869402309),
#  ('project', -1.0427070109800953),
#  ('stuff', 1.0425179695093438),
#  ('cohen', 1.042278144623771),
#  ('desperate', 1.0417913423223433),
#  ('regime', 1.0402252210778056),
#  ('tradition', -1.0400861028984683),
#  ('angeles', 1.0394005355673372),
#  ('beneficiary', 1.037919350491098),
#  ('build', 1.037570518035198),
#  ('level', 1.0375666720601195),
#  ('egypt', -1.0373788601979852),
#  ('medicaid', -1.0372963080832882),
#  ('france', -1.0370246320706793),
#  ('bizarre', 1.0361033180201324),
#  ('expansion', 1.0359664001612952),
#  ('chicago', -1.0355144813883517),
#  ('model', 1.0345261972830606),
#  ('2012', -1.034276342890775),
#  ('coordinator', -1.0338665337228687),
#  ('40', -1.0313876127106099),
#  ('gop', 1.0310912201405416),
#  ('prediction', -1.0305706408082154),
#  ('justify', 1.0298159424388984),
#  ('card', 1.0295473348780235),
#  ('lawmaker', -1.0292451217400036),
#  ('dollar', 1.0289674314710235),
#  ('rep.', 1.0286192336090174),
#  ('bathroom', 1.0271794247145738),
#  ('sen.', -1.0259952425872578),
#  ('cliff', -1.0259862331023277),
#  ('injure', -1.0257036835898674),
#  ('stick', 1.0253781409594696),
#  ('shocking', 1.0229160898941407),
#  ('obtain', 1.0228779725503392),
#  ('network', 1.0227027385208796),
#  ('islam', 1.0225414009192333),
#  ('advisory', -1.0220955666467715),
#  ('hard', -1.0219893464267042),
#  ('reveal', 1.0206196830352743),
#  ('sanchez', -1.020084582558525),
#  ('66', -1.0195635737151452),
#  ('inventory', 1.0195215546147856),
#  ('friendship', -1.0194197964019103),
#  ('resume', 1.0191620452347143),
#  ('boehner', 1.019026813957308),
#  ('resort', 1.0186699058023214),
#  ('bargaining', 1.0185730649553786),
#  ('congressman', 1.0170098971349908),
#  ('flow', 1.0167915888188797),
#  ('neglect', 1.0159875816373356),
#  ('operator', 1.015211035809351),
#  ('deposit', -1.0151882330201647),
#  ('racial', 1.0150010019564095),
#  ('operative', 1.0146088849688495),
#  ('funeral', 1.0144030065888647),
#  ('hat', 1.0125279280005677),
#  ('subject', 1.0112506059333535),
#  ('bloomberg', -1.010792239295635),
#  ('suppose', 1.0106311959019778),
#  ('haiti', 1.010484119527489),
#  ('spread', 1.0102786865828928),
#  ('states', 1.0101877045903733),
#  ('freshman', -1.0096368992973168),
#  ('sp', 1.009373235246525),
#  ('transgender', -1.0090528484977255),
#  ('mirror', 1.0085709899254265),
#  ('proof', 1.0084975922579487),
#  ('soviet', -1.0082552084698393),
#  ('publication', 1.0081363675745862),
#  ('euro', 1.00772581103184),
#  ('innovation', -1.007268645906452),
#  ('blast', 1.0069009448242772),
#  ('iraqi', 1.0061539849466123),
#  ('england', -1.0060860964209632),
#  ('truly', 1.005511500983369),
#  ('ski', -1.0054360708111367),
#  ('enjoy', -1.0051659129304682),
#  ('cairo', -1.0046957100131984),
#  ('spiritual', -1.0041916993400963),
#  ('jeb', -1.0038082945029398),
#  ('london', -1.0036414585647782),
#  ('century', 1.0034863484405636),
#  ('fda', 1.0030702980631085),
#  ('"', -1.0024393665701892),
#  ('balloon', -1.0024111216897238),
#  ('datum', 1.0020519438502267),
#  ('52', -1.0018291273145226),
#  ('score', -1.0014812211776878),
#  ('interested', -1.001447860913583),
#  ('subpoena', 1.001404545675662),
#  ('oversight', 1.0013982579867273),
#  ('surprising', 1.000959970715084),
#  ('argue', -1.000680402255148),
#  ('jan', -1.0002675895231774),
#  ('major', 0.9999774923723546),
#  ('stein', 0.9998429009740701),
#  ('allegation', -0.9997096843223752),
#  ('rap', 0.9990122697354954),
#  ('declare', 0.9988345028880387),
#  ('worker', 0.9980975927854897),
#  ('relationship', -0.9977920932437013),
#  ('suggestion', -0.9962538555514953),
#  ('receiver', -0.9959816163024576),
#  ('desert', -0.9959747657126578),
#  ('plenty', -0.9953941866559416),
#  ('dr.', 0.9952563024727976),
#  ('delay', 0.9950361878902166),
#  ('st.', -0.9946891316832532),
#  ('jerusalem', -0.9939217363082914),
#  ('manhattan', 0.9928692408771544),
#  ('train', -0.9928311192569992),
#  ('michael', -0.9928065519452139),
#  ('friends', 0.9923624528516266),
#  ('displace', -0.9918100571162378),
#  ('hotel', 0.9909424419757682),
#  ('ceo', 0.9905538912005291),
#  ('just', 0.9902095010702627),
#  ('match', -0.9899448729702401),
#  ('basket', -0.9897541382582024),
#  ('pruitt', -0.9895915029772544),
#  ('grassroots', 0.9894047232650492),
#  ('address', -0.9886419964965267),
#  ('howard', -0.9882847623536029),
#  ('selection', -0.9871428875850395),
#  ('affiliate', -0.9866616300199282),
#  ('imperial', 0.986525583613729),
#  ('big', 0.9861276568509179),
#  ('motor', 0.9858422123811179),
#  ('locate', -0.9846987398970791),
#  ('transfer', -0.9842211152949228),
#  ('need', -0.9841131587022204),
#  ('nurse', 0.9840410628980174),
#  ('poland', -0.9839853947237629),
#  ('1,000', -0.9837561539757514),
#  ('25', -0.9835195122521422),
#  ('infrastructure', 0.983306911225921),
#  ('post', 0.9831561106993096),
#  ('handful', 0.9828635892020309),
#  ('walter', -0.9813625697398933),
#  ('regain', -0.9795337976019288),
#  ('crisis', 0.9794972517400716),
#  ('downtown', -0.9789787466928264),
#  ('fail', 0.978633902038008),
#  ('sale', 0.9770221570304521),
#  ('homer', -0.9763767389633259),
#  ('awards', -0.9754991637070358),
#  ('intel', 0.9748685983731595),
#  ('amid', -0.9744445603404189),
#  ('text', -0.9735072664852062),
#  ('lebanon', 0.9733181415632448),
#  ('collapse', 0.9725766327834555),
#  ('yellow', -0.9718177616446378),
#  ('28', -0.9707221183014975),
#  ('retaliation', -0.9694032541309423),
#  ('bowl', -0.9684245797926965),
#  ('ali', 0.9681281721561454),
#  ('u.n.', -0.9681217133559025),
#  ('magazine', -0.9674051969993895),
#  ('annual', -0.9671501609406832),
#  ...]

# %% [markdown]
# # remove tokens overrepresented in the dataset from vocabulary (they are likely publisher-related)

# %% [markdown]
# See 4.1 in the paper.

# %%
def examine_tokens(df, token):
    num = 0
    for index, row in df.iterrows():
        if token in row['text_lemmas']:
            num += 1
            if num <= 20:
                print(row['text'])
    return num

# %%
def token_disparity(x_train, x_test, tokens):
    for token in tokens:
        token = str(token[0])
        train_count = 0
        for train_item in x_train:
            train_count += train_item.count(token)
        test_count = 0
        for test_item in x_test:
            test_count += test_item.count(token)
        train_norm = train_count/len(x_train)
        test_norm = test_count/len(x_test)
        if test_norm == 0:
            val = 'does not appear in test'
            print(token)
        else:
            val = train_norm/test_norm
            if val > 5:
                print(token)

# %%
token_disparity(x_train, x_test, lr_count_uni)
# Out:
# abq
# new mexico
# lobo
# lobos
# truthdigger
# lottery
# apd
# topes
# tope
# aggie
# nmsu
# editorial
# baptists
# sbc
# albuquerque
# calwatchdog
# cruces
# pnm
# forex
# goings
# lanl
# slumped
# sandia
# jumped
# carlsbad
# farmington
# cbf
# mojo
# gsk
# brodner
# wipp
# taos
# chatter
# navajo
# cnm
# bernalillo
# rancho
# diocese
# mulesoft
# roswell
# bosque
# i-25
# i-40
# paseo
# fmr
# councilor
# earnings
# playoff
# mudslide
# cps
# pearce
# sandoval
# baptist
# cueva
# shares
# therapeutics
# cibola
# tourney
# ™
# 5a
# fiesta
# popped
# mwc
# bcso
# factcheck
# stocks
# udall
# investors
# rapture
# exhibition
# archdiocese
# tariff
# scheer
# grain
# priest
# mesa
# futures
# traders
# clovis
# skier
# j.c.
# 6a
# snapshot
# cardinals
# aussie
# resorts
# viking
# opener
# ministry
# pharmaceuticals
# slaying
# dividend
# ltd.
# dividends
# climbs
# clergy
# evening’
# selloff
# p.m.
# brands
# avalanche
# motors
# jaguar
# armour
# lifts
# plc
# corp.
# fitbit
# procter
# inc.
# sciences
# nvidia
# 401(k
# ftse
# recalls
# embezzlement
# volleyball
# quarterly
# hsbc
# chipotle
# pretribulation
# midday’
# 5’
# pfizer
# volume
# valeant
# nokia
# amazon.com
# nasdaq
# pct
# biotech
# highs
# gopro
# gallery
# aramco
# cash’
# pandora
# lotto
# gilead
# oracle
# lilly
# holdings
# mln
# 3q
# tips
# samsung
# boeing
# north carolina
# citigroup
# ufc
# shareholder
# verizon
# caterpillar
# icahn
# fiat
# cambridge
# 30-year
# factbox
# cubs
# nyse
# viacom
# buyout
# yellen
# cfo
# alphabet
# buyback
# trading
# at&t
# blackberry
# berkshire
# lotto’
# ibm
# nhl
# foreclosure
# merck
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f936c3ffcc05> in <module>()
# ----> 1 token_disparity(x_train, x_test, lr_count_uni)
#
# <ipython-input-16-bdcfca322594> in token_disparity(x_train, x_test, tokens)
#       4         train_count = 0
#       5         for train_item in x_train:
# ----> 6             train_count += train_item.count(token)
#       7         test_count = 0
#       8         for test_item in x_test:
#
# KeyboardInterrupt:

# %%
token_disparity(x_train, x_test, mapping)
# Out:
# thomson
# councilor
# jackpot
# romero
# seminary
# slideshow
# lobos
# navajo
# lobo
# touchdown
# rebound
# innings
# scoring
# gardner
# playoff
# composite
# investing
# quarterback
# sophomore
# coach
# millions
# championship
# powerball
# qualcomm
# tournament
# gadget
# tesla
# ncaa
# wynn
# payout
# midday
# retailer
# chipotle
# alphabet
# hockey
# alamos
# teammate
# holdings
# halftime

# %% [markdown]
# # upgraded vectorization - own counter

# %%
from collections import Counter
import re

# %%
def dummy_two(doc):
    # use as param in vectorizers
    return doc

# %%
def countvocab(text_lemmas):
    
    vocab = Counter()
    word = re.compile('[a-z]*\Z')
    
    except_file = open('token_exceptions.txt')
    exceptions = except_file.read().split('\n')
    except_file.close()
    stopwords_file = open('sklearn_stopwords.txt')
    stopwords = stopwords_file.read().split('\n')
    stopwords_file.close()
    
    for text in text_lemmas:
        for token in ast.literal_eval(text):
            if word.match(token) == None:
                continue
            if token in exceptions:
                continue
            if token in stopwords:
                continue
            vocab[token] += 1
    
    return [couple[0] for couple in vocab.most_common(4000)]

# %%
vocab = countvocab(x_train)

# %%
vocab_file = open('vocab.txt', 'w')
for word in vocab:
    vocab_file.write(word+'\n')
vocab_file.close()

# %%
count_uni = CountVectorizer(vocabulary = vocab,
                    analyzer='word',
                    tokenizer=dummy_two,
                    preprocessor=None,
                    lowercase = False)

# %%
train_fvs = count_uni.transform(x_train)

# %%
test_fvs = count_uni.transform(x_test)

# %%
def count_fvs(text):
    
    text = ast.literal_eval(text)
    
    vector = [0]*len(vocab)
    
    for idx in range(len(vocab)):
        vector[idx] = text.count(vocab[idx])
    
    return vector

# %%
train_fvs = x_train.apply(count_fvs)
test_fvs = x_test.apply(count_fvs)

# %%
# Unigram logistic regression with updated vocabulary

model = lr.fit(train_fvs, y_train)
y_pred = model.predict(test_fvs)
    
acc = sk.metrics.accuracy_score(y_test, y_pred)
print("accuracy: {0:.2f}%".format(acc*100))
    
mapping = list(zip(vocab, model.coef_[0]))
mapping.sort(key=lambda x: abs(x[1]))
mapping.reverse()

# %%
mapping

# %%
pickle.dump(model, open('hyperpartisan-model.sav', 'wb'))

# %% [markdown]
# # Evaluation

# %%
# Read datasets, read hyperpartisan model, give percentages.
