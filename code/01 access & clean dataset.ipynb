# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io
import re
import glob
import dask.dataframe as dd
import nltk

# %% [markdown]
# # access dataset from xml file

# %% [markdown]
# Read XML files that are provided from SemEval. Put them into dataframes.

# %%
test_df = pd.DataFrame()
train_df = pd.DataFrame()
byarticle_df = pd.DataFrame()

# %%
test_path = 'data/articles-validation-bypublisher-20181122.xml'
train_path = 'data/articles-training-bypublisher-20181122.xml'
test_path_truth = 'data/ground-truth-validation-bypublisher-20181122.xml'
train_path_truth = 'data/ground-truth-training-bypublisher-20181122.xml'

byarticle_path = 'data/articles-training-byarticle-20181122.xml'
byarticle_truth = 'data/ground-truth-training-byarticle-20181122.xml'

# %%
def etparse(df, path_articles, path_truth, bias_val = True):
    
    tree_art = ET.parse(path_articles)
    tree_truth = ET.parse(path_truth)
    root_art = tree_art.getroot()
    root_truth = tree_truth.getroot()
    
    texts = []
    titles = []
    label = []
    bias = []
    
    for article in root_art:
        texts.append(''.join(article.itertext()))
        titles.append(article.attrib['title'])
        
    for article in root_truth:
        label.append(article.attrib['hyperpartisan'])
        if bias_val:
            bias.append(article.attrib['bias'])
        
    assert len(texts) == len(titles) == len(label)
    if bias_val:
        assert len(texts) == len(bias)
    
    df['title'] = titles
    df['text'] = texts
    df['label'] = label
    if bias_val:
        df['bias'] = bias
    
    return df

# %%
test_df = etparse(test_df, test_path, test_path_truth)

# %%
train_df = etparse(train_df, train_path, train_path_truth)

# %%
byarticle_df = etparse(byarticle_df, byarticle_path, byarticle_truth, False)

# %% [markdown]
# # cleaning

# %% [markdown]
# Initial cleaning: special characters, certain recurring error patterns, leftover html.

# %%
def clean_text(text):
    text = text.replace('&#160;', ' ')
    text = text.replace("\n", '')
    text = text.replace("\r", '')
    text = text.replace("  ", ' ')
    text = text.replace(" ? ", " ")
    text = text.replace('.......... ', '')
    text = text.replace('&amp;', '')
    text = text.replace('[…] ', '')
    text = text.replace('[...] ', '')
    text = text.replace(' |', '')
    text = text.replace('Continue Reading Below ', '')
    
    text = re.sub(r"(?<=\w)[/?](?=\w)", "'", text) # any ? preceded by & followed immediately by a letter. Here?s group?s It?s
    text = re.sub(r"\bNone\b[ ](?=[A-Z])", "", text) # blah blah. None In the end -> leftovers from XML file
    text = re.sub(r"[/?][^ ][^/?]*[^ ][/?]", lambda x: x.group()[1:-1], text) # ?gun control?
    text = re.sub(r"&lt;.*&gt;", "", text) # remove img/html tags
    text = re.sub(r'(^|[^@\w])@(\w{1,15})\b', '\\1@TWITTER', text) # replace all twitter UN with @TWITTER
    
    text = text.replace('&gt;', '')
    text = text.replace('&lt;', '')
    
    return text

# %%
test_df['text'] = test_df['text'].apply(clean_text)

# %%
train_df['text'] = train_df['text'].apply(clean_text)

# %%
byarticle_df['text'] = byarticle_df['text'].apply(clean_text)

# %% [markdown]
# # further cleaning - remove certain symbols/names

# %% [markdown]
# More complicated cleaning: phrases discovered in texts that could be publisher-specific, more special characters.

# %%
from nltk.tokenize import sent_tokenize

# %%
def further_clean(text):
    
    sents = sent_tokenize(text)
    
    remove = [' ©', '© ', 'Opens a New Window', 'click here', 'follow us', 'https:', '.html', 'read full article',
             'a href', 'originally published', 'image source: ']
    
    new_text = []
    
    email = re.compile(r"[^@ ]+@[^@]+")
    
    for item in sents:
        add = True
        for term in remove:
            if term in item:
                add = False
        if '©' == item[0]:
            add = False
        if 'photo by' in item.lower() and len(item) < 50:
            add = False
        if 'read more' in item.lower() and len(item) < 50:
            add = False
        if 'featured image' in item.lower() and len(item) < 100:
            add = False
        if item[0] == '[' and item[-1] == ']':
            if len(item) < 50:
                add = False
            if '.' not in item:
                add = False
            if add:
                item = item[1:-1]
        if item[0] == '(' and item[-1] == ')' and '.' not in item and '!' not in item and '?' not in item:
            add = False
        if email.match(item):
            add = False
        if len(email.findall(item)) > 0 and '@TWITTER' not in item:
            add = False
            
        if ') —' in item[:50]:
            item = item[item.find('—')+2:]
        
        if add:
            new_text.append(item)
                
    return ' '.join(new_text)

# %%
test_df['text'] = test_df['text'].apply(further_clean)

# %%
train_df['text'] = train_df['text'].apply(further_clean)

# %%
byarticle_df['text'] = byarticle_df['text'].apply(further_clean)

# %% [markdown]
# # Handle NaN

# %% [markdown]
# Some articles came without titles or even texts (presumably by mistake). Any empty texts here are replaced with the empty string instead of NaN to prevent problems later.

# %%
def check_str(text):
    if type(text) != str:
        print(text)
        return ''
    else:
        return text

# %%
test_df['text'] = test_df['text'].apply(check_str)

# %%
train_df['text'] = train_df['text'].apply(check_str)

# %%
byarticle_df['text'] = byarticle_df['text'].apply(check_str)

# %% [markdown]
# # save

# %% [markdown]
# Save pandas dataframes as csv for later.

# %%
test_df.to_csv('data/test_df.csv', index=False)

# %%
train_df.to_csv('data/train_df.csv', index=False)

# %%
byarticle_df.to_csv('data/byarticle_df.csv', index=False)

# %%
train_df
# Out:
#                                                     title  \
# 0       After DeVos Announced Plans To Reexamine Title...
# 1       University To Award Trayvon Martin With Posthu...
# 2       Texas State University suspends Greek life aft...
# 3       Jewish Organization's Huge Day Of Unity On Tue...
# 4       BREAKING: Trump Reaches Agreement To Keep 1,00...
# 5                  Winning numbers drawn in ‘2 By 2’ game
# 6       Health insurance stocks slump in face of poten...
# 7       ANALYSIS: Does gay debate mirror church disput...
# 8       How schools in Brazil are teaching kids to eat...
# 9       Massive venomous snake found under New Orleans...
# 10      VIDEO: U.S. Reaches Trans-Pacific Partnership ...
# 11      Trump’s Desperate Attempt to Distract American...
# 12      With tensions high, protests erupt across Vene...
# 13      Survey: Nearly 80 Percent of Americans Live Pa...
# 14      Time to learn whether top-secret pages tie Sau...
# 15      Touch new stamp and presto, total solar eclips...
# 16                     Where is Apple’s ‘Next Big Thing’?
# 12      New clashes erupted Thursday between Venezuela...  false   left-center
# 13      Nearly 80 percent of Americans are living payc...  false  right-center
# 14      Moussaoui is serving a life sentence for his i...  false         least
# 15      Just touch the stamp with your finger, and the...  false         least
# 16       Bad news for Apple (NASDAQ:AAPL): The company...   true         right
# 17      Currently there is a bit of a “civil war” goin...   true          left
# 18      Don’t get me wrong, rape—on college campuses o...   true         right
# 19      Peter LaBarbera is claiming that gays, or, as ...   true          left
# 20      A Rhode Island public school district has been...  false         least
# 21      Staples announced Tuesday that it would close ...  false   left-center
# 22      — David L. Otero, Albuquerque WOW! LEAVE IT UP...  false         least
# 23      Chris Matthews was on a roll last night. First...   true         right
# 24       Richardson is suspending all hiring during th...  false         least
# 25       International Monetary Fund Managing Director...   true         right
# 26      Empires die. Some abruptly, by cataclysmic def...   true          left
# 27      I jumped in the car with two of the young peop...   true          left
# 28      The President of the United States left Washin...   true          left
# 29      Santa Fe Police spokeswoman Celina Westervelt ...  false         least
# ...                                                   ...    ...           ...
# 599970  HOUSTON - Houston police say a stabbing suspec...  false         least
# 599971  AT LEAST FOR THE MOMENT, Women's Liberation is...   true          left
# 599972  A U.S. judge on Monday denied Apple Inc's requ...   true         right
# 599973  Eric Sikola has been looking at expense report...   true         right
# 599974  Truth be told, the only reason I buy coffee at...  false         least
# 599975  Two years ago, the top honchos at the Fed, Tre...   true          left
# 599976  Yesterday, in New York, Michael Eisner shared ...   true          left
# 599977  CHEYENNE, Wyo. Firearms manufacturer Weatherby...  false         least
# 599978  Virtual reality is one of the most exciting in...  false  right-center
# 599979  An explosives-strapped diesel tanker blew up n...  false   left-center
# 599980  Ask most Americans about terrorist attacks com...   true          left
# 599981   On Monday, Matt Barber, founder and Editor-in...   true         right
# 599982   It’s a long way to the Dem’s August conventio...   true          left
# 599983  Patrick Caldwell'Mother Jones “I almost had a ...   true          left
# 599984  “ Saturday Night Live” will continue its live ...  false  right-center
# 599985  ATT, Inc. (T) will report its next earnings on...  false  right-center
# 599986  Point guard Jaylen Fisher could miss the rest ...  false         least
# 599987  A few weeks ago, Brazilian President Dilma Rou...  false   left-center
# 599988   Swedish measurement technology and software f...   true         right
# 599989  UPPER MARLBORO, Md. A man accused of setting o...  false         least
# 599990  Chris Hemsworth, left, and Jessica Chastain ap...  false         least
# 599991  Call it a Santa Claus Rally -- stocks surged t...   true         right
# 599992  ATLANTA (AP) _ The winning numbers in Monday m...  false         least
# 599993  The majority of the police force in the Mexica...  false   left-center
# 599994  US Sen. John Kerry, the top Democrat on the Se...  false   left-center
# 599995  LOS ANGELES (AP) - John Boyega may have a lot ...  false         least
# 599996   Kiribati lidian'Shutterstock In climate negot...   true          left
# 599997  The Little Red Hamburger Hut, near Old Town, i...  false         least
# 599998  It's an important week for the Republican-led ...  false   left-center
# 599999  Tencent Holdings Ltd., the rapidly growing Chi...   true         right
#
# [600000 rows x 4 columns]
